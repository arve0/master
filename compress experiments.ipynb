# %%
import matrixscreener.experiment as mse

# %%
e = mse.Experiment('data/new_software/experiment--2015_02_09_19_12_35/')

# %%
e.compress()
# Out:
# ['data/new_software/experiment--2015_02_09_19_12_35/slide--S00/chamber--U00--V00/field--X00--Y00/image--L0000--S00--U00--V00--J13--E00--O00--X00--Y00--T0000--Z00--C00.png',
#  'data/new_software/experiment--2015_02_09_19_12_35/slide--S00/chamber--U00--V00/field--X00--Y01/image--L0000--S00--U00--V00--J13--E00--O00--X00--Y01--T0000--Z00--C00.png',
#  'data/new_software/experiment--2015_02_09_19_12_35/slide--S00/chamber--U00--V00/field--X00--Y02/image--L0000--S00--U00--V00--J13--E00--O00--X00--Y02--T0000--Z00--C00.png',
#  'data/new_software/experiment--2015_02_09_19_12_35/slide--S00/chamber--U00--V00/field--X00--Y03/image--L0000--S00--U00--V00--J13--E00--O00--X00--Y03--T0000--Z00--C00.png',
#  'data/new_software/experiment--2015_02_09_19_12_35/slide--S00/chamber--U00--V00/field--X00--Y04/image--L0000--S00--U00--V00--J13--E00--O00--X00--Y04--T0000--Z00--C00.png',
# ...

# %%
# !du -h -d0 $e.path
# Out:
#  55M	/Users/arve/Dokumenter/git/master/data/new_software/experiment--2015_02_09_19_12_35

# %%
from IPython import display

# %%
display.Image(e.images[-1])

# %%
# !find $e.path -name *tif -delete

# %%
# !du -h -d0 $e.path
# Out:
#  48M	/Users/arve/Dokumenter/git/master/data/new_software/experiment--2015_02_09_19_12_35

# %%
# !ls -lh data/new_software/experiment--2015_02_09_19_12_35/slide--S00/chamber--U00--V00/field--X00--Y00/metadata/image--L0000--S00--U00--V00--J13--E00--O00--X00--Y00--T0000.ome.xml
# Out:
# -rwx---r-x  1 arve  staff   157K Feb  9 20:12 data/new_software/experiment--2015_02_09_19_12_35/slide--S00/chamber--U00--V00/field--X00--Y00/metadata/image--L0000--S00--U00--V00--J13--E00--O00--X00--Y00--T0000.ome.xml

# %% [markdown]
# 157K metadata, that's a lot!
