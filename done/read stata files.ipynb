# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
s = pd.Series([1,3,5,np.nan,6,8])

# %%
s
# Out:
# 0     1
# 1     3
# 2     5
# 3   NaN
# 4     6
# 5     8
# dtype: float64

# %%
data = pd.read_stata('data/klinisk_data.dta', convert_categoricals=False)

# %%
for c in data.columns:
    print('-', c)
# Out:
# - person_id
# - ID_deltaker
# - ER_10_prosent
# - ER_1_prosent
# - PR_10_prosent
# - HER2
# - Ki67
# - Ck5
# - Ck14
# - EGFR
# - TP_nr
# - Size_A
# - Size_min_A
# - str_Anna
# - Storrelse_histopatologisk
# - str_hp_oppr
# - str_crude
# - str_2_5
# - Storrelse_klinisk
# - Kliniske_funn_hud_fascie
# - met_brystalle
# - stadium_brystalle
# - Ant_lkn_us
# - Ant_lkn_met
# - lkn_status
# - Vaktpostlkn
# - Ark_A
# - brystkreft_NT
# - type_dlmpo
# - papil_rev
# - Alder_ved_S1
# - Mitoses1
# - Utgaar_sikkert
# - Utgaar_forelopig
# - Utgaar_lab
# - ID_sykdom1
# - Provenr101
# - Preparatnr101
# - Aarstall_prove101
# - Provenr102
# - Preparatnr102
# - Aarstall_prove102
# - Aarstall_prøve103
# - Aarstall1_tumor1
# - Prove1_lkn1
# - Preparatnr1_lkn1
# - Opr_type_kat
# - Side_r
# - Size_A1
# - Size_min_A1
# - Size_A2
# - Size_min_A2
# - inkl
# - MITOSER
# - Ark_O
# - TYPE
# - GRAD
# - sykdom_id1
# - ds1num
# - diagnosedato1
# - lok_icd71
# - lok1
# - topografi1
# - hist_motnac1
# - morfologi1
# ...

# %%
data.loc[:, ['ID_deltaker', 'TP_nr']]
# Out:
#       ID_deltaker  TP_nr
# 0               1      1
# 1               2      1
# 2               3    NaN
# 3               4      1
# 4               6    NaN
# 5               7      1
# 6               8      1
# 7               9    NaN
# 8              10      1
# 9              11    NaN
# 10             12      1
# 11             13    NaN
# 12             14      1
# 13             15      1
# 14             16      1
# 15             17      1
# 16             18      1
# 17             19      1
# 18             20      1
# 19             21      1
# 20             22    NaN
# 21             23      1
# 22             24      1
# 23             25      1
# 24             26      1
# 25             27      1
# 26             28      1
# 27             29      1
# 28             31      1
# 29             32      1
# ...           ...    ...
# 1026         3039     21
# 1027         3040     21
# 1028         3041     21
# 1029         3042     21
# 1030         3043     21
# ...

# %%
sum(data.GRAD[np.isfinite(data.GRAD)])
# Out:
# 3053.0

# %%
sum(data.GRAD1) + 2*sum(data.GRAD2) + 3*sum(data.GRAD3)
# Out:
# 2030.0

# %%
grad2 == grad3
# Out:
#      person_id ID_deltaker ER_10_prosent ER_1_prosent PR_10_prosent   HER2  \
# 0         True        True          True         True          True   True
# 1         True        True          True         True          True   True
# 2         True        True         False        False         False  False
# 3         True        True          True         True          True   True
# 4         True        True         False        False         False  False
# 5         True        True          True         True          True   True
# 6         True        True          True         True          True   True
# 7         True        True         False        False         False  False
# 8         True        True          True         True          True   True
# 9         True        True         False        False         False  False
# 10        True        True          True         True          True   True
# ...

# %%
grad2
# Out:
#       person_id  ID_deltaker  ER_10_prosent  ER_1_prosent  PR_10_prosent  \
# 0         83522            1              1             1              0
# 1          3160            2              0             0              0
# 2         34371            3            NaN           NaN            NaN
# 3         42852            4              1             1              0
# 4          5557            6            NaN           NaN            NaN
# 5         25239            7              1             1              1
# 6         31225            8              1             1              1
# 7         73609            9            NaN           NaN            NaN
# 8         35045           10              1             1              1
# 9         52193           11            NaN           NaN            NaN
# 10        79932           12              1             1              1
# 11        19076           13            NaN           NaN            NaN
# ...

# %%
grad3
# Out:
#       person_id  ID_deltaker  ER_10_prosent  ER_1_prosent  PR_10_prosent  \
# 0         83522            1              1             1              0
# 1          3160            2              0             0              0
# 2         34371            3            NaN           NaN            NaN
# 3         42852            4              1             1              0
# 4          5557            6            NaN           NaN            NaN
# 5         25239            7              1             1              1
# 6         31225            8              1             1              1
# 7         73609            9            NaN           NaN            NaN
# 8         35045           10              1             1              1
# 9         52193           11            NaN           NaN            NaN
# 10        79932           12              1             1              1
# 11        19076           13            NaN           NaN            NaN
# ...

# %%
len(data.index)
# Out:
# 1056

# %%
data.index[-1]
# Out:
# 1055

# %%
data.loc[data.ID_deltaker == 21, 'GRAD']
# Out:
# 19    2
# Name: GRAD, dtype: float32

# %%
sum(data.GRAD1)
# Out:
# 120.0

# %%
sum(data.GRAD == 1)
# Out:
# 122

# %%
data.loc[data.ID_deltaker == 3067]
# Out:
#       person_id  ID_deltaker  ER_10_prosent  ER_1_prosent  PR_10_prosent  \
# 1054      30705         3067              0             0              0
#
#       HER2  Ki67  Ck5  Ck14  EGFR   ...    betCat  AR  ECad_intensitet  \
# 1054     0     0    1     0     0   ...         0   0                9
#
#       nodestatus Ecad_Node  Supersubtyper  TNsubtyper  NonLum alder65 alder70
# 1054           4       NaN            NaN           3       3       1       1
#
# [1 rows x 347 columns]

# %%
# Out:
# 3      4
# 19    21
# 22    24
# 42    45
# 51    55
# Name: ID_deltaker, dtype: int16

# %%
# !head data/lobular.txt
# Out:
# ID-nr p� alle lobul�re
# ID_deltake     TYPE
#          lob      Total
# 4          1          1
# 21          1          1
# 24          1          1
# 45          1          1
# 55          1          1
# 60          1          1
# 62          1          1

# %%
data.loc[np.isfinite(data['GRAD']),('ID_deltaker', 'GRAD')]
# Out:
#       ID_deltaker  GRAD
# 0               1     3
# 1               2     3
# 3               4     2
# 5               7     2
# 6               8     2
# 8              10     3
# 10             12     3
# 12             14     2
# 13             15     3
# 14             16     3
# 15             17     3
# 16             18     2
# 17             19     3
# 18             20     2
# 19             21     2
# 21             23     1
# 22             24     2
# 23             25     2
# 24             26     2
# 25             27     2
# 26             28     1
# 27             29     3
# 28             31     2
# 29             32     1
# 30             33     3
# 32             35     2
# 33             36     2
# 34             37     2
# 35             38     2
# 36             39     1
# ...           ...   ...
# 1020         3033     2
# 1021         3034     2
# 1022         3035     3
# 1023         3036     2
# 1024         3037     2
# 1025         3038     3
# ...

# %%
help(data.at)
# Out:
# Help on _AtIndexer in module pandas.core.indexing object:
#
# class _AtIndexer(_ScalarAccessIndexer)
#  |  Fast label-based scalar accessor
#  |
#  |  Similarly to ``loc``, ``at`` provides **label** based scalar lookups.
#  |  You can also set using these indexers.
#  |
#  |  Method resolution order:
#  |      _AtIndexer
#  |      _ScalarAccessIndexer
#  |      _NDFrameIndexer
#  |      builtins.object
#  |
#  |  Methods inherited from _ScalarAccessIndexer:
#  |
#  |  __getitem__(self, key)
#  |
#  |  __setitem__(self, key, value)
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from _NDFrameIndexer:
#  |
#  |  __call__(self, *args, **kwargs)
#  |
#  |  __init__(self, obj, name)
#  |
#  |  __iter__(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from _NDFrameIndexer:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
# ...

# %%
help(data.iat)
# Out:
# Help on _iAtIndexer in module pandas.core.indexing object:
#
# class _iAtIndexer(_ScalarAccessIndexer)
#  |  Fast integer location scalar accessor.
#  |
#  |  Similarly to ``iloc``, ``iat`` provides **integer** based lookups.
#  |  You can also set using these indexers.
#  |
#  |  Method resolution order:
#  |      _iAtIndexer
#  |      _ScalarAccessIndexer
#  |      _NDFrameIndexer
#  |      builtins.object
#  |
#  |  Methods inherited from _ScalarAccessIndexer:
#  |
#  |  __getitem__(self, key)
#  |
#  |  __setitem__(self, key, value)
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from _NDFrameIndexer:
#  |
#  |  __call__(self, *args, **kwargs)
#  |
#  |  __init__(self, obj, name)
#  |
#  |  __iter__(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from _NDFrameIndexer:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
# ...

# %%
pd.isnull(data.GRAD).head() # True for NaN values
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# Name: GRAD, dtype: bool

# %% [markdown]
# For more, see http://pandas.pydata.org/pandas-docs/stable/10min.html

# %%
np.sum(data.GRAD), np.sum(data.GRAD1) + 2*np.sum(data.GRAD2) + 3*np.sum(data.GRAD3)
# Out:
# (3053.0, 2030.0)
