# %%
# %run utils.ipynb
from leicaautomator import find_spots
# Out:
# /Users/arve/.virtualenvs/3.4/lib/python3.4/site-packages/skimage/viewer/utils/core.py:11: UserWarning: Recommended matplotlib backend is `Agg` for full skimage.viewer functionality.
#   warnings.warn("Recommended matplotlib backend is `Agg` for full "

# %%
e = Experiment('data/experiment--2015_05_04_19_28_38_equalized/')
res = find_spots(e)
# Out:
# Well distance x in microns: 1742.82918647
# Well distance y in microns: 1710.95278865
# ...
# Well offsets
# ...
# ( well )   x[um], y[um]
# -----------------------
# ( 0,  1)    -203,   -40
# ( 0,  2)    -361,    18
# ( 1,  0)     168,    -6
# ( 1,  2)      23,   -94
# ( 1,  3)    -135,  -116
# ( 1,  4)    -156,  -113
# ( 1,  5)    -159,  -177
# ( 1,  6)     117,  -104
# ( 1,  7)     -56,  -107
# ( 1,  8)      65,  -147
# ( 2,  0)      33,  -143
# ( 2,  1)      39,  -213
# ( 2,  2)     -55,  -179
# ( 2,  3)     -19,  -137
# ( 2,  4)     -46,  -231
# ( 2,  5)     -22,  -171
# ( 2,  6)     115,  -110
# ( 2,  7)     191,    -4
# ( 2,  8)      84,  -135
# ( 3,  0)     -20,  -188
# ( 3,  1)     137,  -222
# ( 3,  2)     -45,  -289
# ( 3,  3)    -205,  -310
# ( 3,  4)    -181,  -253
# ( 3,  5)    -187,  -180
# ( 3,  6)     -54,  -129
# ( 3,  7)     -36,  -138
# ( 3,  8)     122,  -199
# ( 4,  0)    -107,  -276
# ( 4,  1)     -62,  -222
# ( 4,  2)     -77,  -295
# ( 4,  3)    -137,  -368
# ...
