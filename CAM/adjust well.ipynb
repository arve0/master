# %% [markdown]
# # algorithm
# - choose top left image
# - for every line in image
#   - fit step function
#   - store best step to list
# - fit sinus function to list
# - from fit decide skewness

# %%
import matrixscreener.experiment as matexp

# %%
adjusted = matexp.Experiment("/Users/arve/Documents/TFY4500/unstained/experiment--row 3-5/")
not_adjusted = matexp.Experiment("/Users/arve/Documents/TFY4500/unstained/experiment--row 0-2//")

# %%
def is_top_left(image):
    import matrixscreener.experiment as e
    return (e.attribute(image, 'X') == '00' and
            e.attribute(image, 'Y') == '00' and
            e.attribute(image, 'C') == '00')

# %%
adjusted_top_left_images = [i for i in adjusted.images if is_top_left(i)]
not_adjusted_top_left_images = [i for i in not_adjusted.images if is_top_left(i)]

# %%
# %pylab inline
from skimage.io import imread
import matplotlib

matplotlib.rcParams['image.interpolation'] = 'none'
matplotlib.rcParams['image.cmap'] = 'gray_r'
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['test']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
# %qtconsole

# %%
def subplot4(images):
    "view all images in columns of 4"
    rows = len(images) // 4 + 1
    figure(figsize(12, 3*rows))
    for i,img in enumerate(images):
        subplot(rows, 4, i+1)
        imshow(imread(img) > 3)

# %%
subplot4(adjusted_top_left_images)

# %%
subplot4(not_adjusted_top_left_images)

# %%
image = imread(adjusted_top_left_images[-3])
imshow(image)

# %%
from skimage.filters import threshold_otsu
threshold_otsu(image)
# Out:
# 17

# %%
imshow(image > 17)

# %%
from skimage import morphology

# %%
convex_hull = morphology.convex_hull_image(image > 17)
imshow(convex_hull)

# %%
from skimage import draw

# %%
erroded = morphology.erosion(image > 1, morphology.disk(radius=3))
imshow(erroded)

# %%
imshow(morphology.convex_hull_image(erroded))

# %%
def pre_processing(filename):
    from skimage.io import imread
    from skimage import morphology
    image = imread(filename)
    image = morphology.erosion(image > 1, morphology.disk(radius=3))
    if np.any(image):
        return morphology.convex_hull_image(image)
    else:
        # empty image
        return image

# %%
def subplot4(images):
    "view all images in columns of 4"
    rows = len(images) // 4 + 1
    figure(figsize(12, 3*rows))
    for i,img in enumerate(images):
        subplot(rows, 4, i+1)
        imshow(pre_processing(img))

# %%
subplot4(adjusted_top_left_images)

# %%
subplot4(not_adjusted_top_left_images)

# %% [markdown]
# Lets try mean instead

# %%
from skimage import filters, morphology
from skimage import img_as_ubyte

# %%
image = filters.rank.mean(imread(adjusted_top_left_images[-3]), morphology.disk(5))
image = morphology.erosion(image, morphology.disk(7))
imshow(image)
colorbar()

# %%
imshow(morphology.convex_hull_image(image > 4))
colorbar()

# %%
def pre_processing(filename):
    from skimage import filters, morphology
    from skimage import img_as_ubyte
    image = filters.rank.mean(imread(filename), morphology.disk(5))
    image = morphology.erosion(image, morphology.star(7))
    image = image > image.min()
    if np.any(image):
        image = morphology.convex_hull_image(image)
    return image

# %%
subplot4(adjusted_top_left_images[0:4])
subplot4(not_adjusted_top_left_images[0:4])
