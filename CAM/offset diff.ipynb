# %% [markdown]
# This notebook will explore differences between templates which have been altered with a well offset in LASAF.

# %%
# %qtconsole

# %%
from pprint import pprint

def pretty_xml(filename):
    "Pretty prints XML in filename."
    import xml.dom.minidom
    import re

    dom = xml.dom.minidom.parse(filename)
    xml = dom.toprettyxml().splitlines()
    
    def keep(string):
        "Return false if string is considered whitespace."
        patterns = [
            re.compile(r'^\t+$'), #only tabs
            re.compile(r'^ +$'),  #only spaces
            re.compile(r'^$') ]   #empty
        for pattern in patterns:
            if pattern.match(string) is not None:
                return False
        return True

    xml = [line for line in xml if keep(line)]
    return xml

# %%
# !ls offset\ diff/orig
# Out:
# {ScanningTemplate}movement diff.lrp {ScanningTemplate}movement diff.xml

# %%
filename = "{ScanningTemplate}movement diff.xml"
root = "offset diff"
comp1 = "dx dy a1"
comp2 = "dx dy b2"
file1 = path.join(root, comp1, filename)
file2 = path.join(root, comp2, filename)

# %%
from os import path
from difflib import Differ

xml_orig = pretty_xml(file1)
xml_diff = pretty_xml(file2)

compare = Differ().compare
diff = compare(xml_orig, xml_diff)
diff_str = "\n".join(diff)

# %%
load(diff_str)

# %% [markdown]
# # XML diff
# Templates:
# - dx dy a1
# - dx dy b2

# %%
# %%writefile diff.xml
#   <?xml version="1.0" ?>
#   <MatrixScreenerTemplate xmlns:xsd="http://www.w3.org/2001/XMLSchema" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance">
#   	<ScanningTemplate>
#   		<Properties TotalAssignedJobs="16" TotalCountOfFields="16" TotalCountOfWells="4" UniqueJobCounter="1" Version="Version: 1.0.4.563 -- Build 08.08.2013">
# - 			<CurrentDate>Tuesday, January 13, 2015 | 10:42 AM</CurrentDate>
# ? 			                                             ^
#
# + 			<CurrentDate>Tuesday, January 13, 2015 | 10:44 AM</CurrentDate>
# ? 			                                             ^
#
#   			<EnableTrigger>false</EnableTrigger>
#   			<TriggerRepeatCycles>1</TriggerRepeatCycles>
#   			<DriftScanRange>5</DriftScanRange>
#   			<DriftSliceCount>5</DriftSliceCount>
#   			<EnableCAM>false</EnableCAM>
#   			<ShowPumpFields>false</ShowPumpFields>
#   			<EnablePump>false</EnablePump>
#   			<PumpRepeatInterval>1</PumpRepeatInterval>
#   			<PumpDelay>1000</PumpDelay>
#   			<PumpTime>1000</PumpTime>
#   			<EnableContextMenu>true</EnableContextMenu>
#   			<ContextType>eMatrixContextStripe</ContextType>
#   			<ScanningTemplateType>eIsMatrixTemplate</ScanningTemplateType>
#   			<EnableTrackRemoveBoundaryObjects>false</EnableTrackRemoveBoundaryObjects>
#   			<EnableTrackRemoveSmallObjects>false</EnableTrackRemoveSmallObjects>
#   			<TrackAdaptiveThreshold>3</TrackAdaptiveThreshold>
#   			<TrackSizeOfSmallObject>15</TrackSizeOfSmallObject>
#   			<TrackRepeatInterval>1</TrackRepeatInterval>
#   			<ShowTrackingFields>false</ShowTrackingFields>
#   			<EnableTracking>false</EnableTracking>
#   			<FixHeigthOfWell>50</FixHeigthOfWell>
#   			<FixWidthOfWell>50</FixWidthOfWell>
#   			<HoldSize>false</HoldSize>
#   			<TextColorHeatMapDescription>808080</TextColorHeatMapDescription>
#   			<DrawRandomizedTestHeatMap>false</DrawRandomizedTestHeatMap>
#   			<EnableLUTBarInAgenda>false</EnableLUTBarInAgenda>
#   			<LUTBarDescription>Focus Map</LUTBarDescription>
#   			<LUTBarUpperText>-- 0.0 µm</LUTBarUpperText>
#   			<LUTBarLowerText>-- 0.0 µm</LUTBarLowerText>
#   			<LUTBarInHeight>144</LUTBarInHeight>
#   			<EnableHeatMap>false</EnableHeatMap>
#   			<HeatMapType>IsFocusMap</HeatMapType>
#   			<HeatMapLUT>LUT_JET</HeatMapLUT>
#   			<ColorWellOutlineSelected>00FF00</ColorWellOutlineSelected>
#   			<ColorInActiveScanField>808080</ColorInActiveScanField>
#   			<ColorScanFieldBoundary>000000</ColorScanFieldBoundary>
#   			<ColorScanFieldForTracking>00FF00</ColorScanFieldForTracking>
#   			<ColorCurrentScanField>00FF00</ColorCurrentScanField>
#   			<ColorActiveScanField>404040</ColorActiveScanField>
#   			<ColorWellOutline>000000</ColorWellOutline>
#   			<ColorWellFilled>23272E</ColorWellFilled>
#   			<EnableMultiSelection>false</EnableMultiSelection>
#   			<ColorSelectedFields>9ACD32</ColorSelectedFields>
#   			<EnableRubberBand>true</EnableRubberBand>
#   			<ColorRubberBand>C00000</ColorRubberBand>
#   			<ScanFieldEffectDesign>None</ScanFieldEffectDesign>
#   			<ScanFieldShapeDesign>IsRectangle</ScanFieldShapeDesign>
#   			<ScanFieldDistanceX>2</ScanFieldDistanceX>
#   			<ScanFieldDistanceY>2</ScanFieldDistanceY>
#   			<ScanFieldDiameter>40</ScanFieldDiameter>
#   			<CountOfScanFieldsX>2</CountOfScanFieldsX>
#   			<CountOfScanFieldsY>2</CountOfScanFieldsY>
#   			<ExperimenTimeDistance>15</ExperimenTimeDistance>
#   			<ExperimentLoopCount>1</ExperimentLoopCount>
#   			<EnableIndividualWellScanFieldCount>false</EnableIndividualWellScanFieldCount>
#   			<DrawWellOutlineIfSelected>false</DrawWellOutlineIfSelected>
#   			<DrawWellOutline>true</DrawWellOutline>
#   			<WellsDistanceX>42</WellsDistanceX>
#   			<WellsDistanceY>42</WellsDistanceY>
#   			<CountOfWellsX>2</CountOfWellsX>
#   			<CountOfWellsY>2</CountOfWellsY>
#   			<TextColorWellplateDescription>808080</TextColorWellplateDescription>
#   			<TextWellPlateHorizontal>A</TextWellPlateHorizontal>
#   			<TextWellPlateHorizontal>B</TextWellPlateHorizontal>
#   			<TextWellPlateHorizontal>C</TextWellPlateHorizontal>
#   			<TextWellPlateHorizontal>D</TextWellPlateHorizontal>
#   			<TextWellPlateHorizontal>E</TextWellPlateHorizontal>
#   			<TextWellPlateHorizontal>F</TextWellPlateHorizontal>
#   			<TextWellPlateHorizontal>G</TextWellPlateHorizontal>
#   			<TextWellPlateHorizontal>H</TextWellPlateHorizontal>
#   			<TextWellPlateHorizontal>I</TextWellPlateHorizontal>
#   			<TextWellPlateHorizontal>J</TextWellPlateHorizontal>
#   			<TextWellPlateHorizontal>K</TextWellPlateHorizontal>
#   			<TextWellPlateHorizontal>L</TextWellPlateHorizontal>
#   			<TextWellPlateHorizontal>M</TextWellPlateHorizontal>
#   			<TextWellPlateHorizontal>N</TextWellPlateHorizontal>
#   			<TextWellPlateHorizontal>O</TextWellPlateHorizontal>
#   			<TextWellPlateHorizontal>P</TextWellPlateHorizontal>
#   			<TextWellPlateHorizontal>Q</TextWellPlateHorizontal>
#   			<TextWellPlateHorizontal>R</TextWellPlateHorizontal>
#   			<TextWellPlateHorizontal>S</TextWellPlateHorizontal>
#   			<TextWellPlateHorizontal>T</TextWellPlateHorizontal>
#   			<TextWellPlateHorizontal>U</TextWellPlateHorizontal>
#   			<TextWellPlateHorizontal>V</TextWellPlateHorizontal>
#   			<TextWellPlateHorizontal>W</TextWellPlateHorizontal>
#   			<TextWellPlateHorizontal>X</TextWellPlateHorizontal>
#   			<TextWellPlateHorizontal>Y</TextWellPlateHorizontal>
#   			<TextWellPlateHorizontal>Z</TextWellPlateHorizontal>
#   			<TextWellPlateHorizontal>AA</TextWellPlateHorizontal>
#   			<TextWellPlateHorizontal>BB</TextWellPlateHorizontal>
#   			<TextWellPlateHorizontal>CC</TextWellPlateHorizontal>
#   			<TextWellPlateHorizontal>DD</TextWellPlateHorizontal>
#   			<TextWellPlateHorizontal>EE</TextWellPlateHorizontal>
#   			<TextWellPlateHorizontal>FF</TextWellPlateHorizontal>
#   			<TextWellPlateHorizontal>AB</TextWellPlateHorizontal>
#   			<TextWellPlateHorizontal>AC</TextWellPlateHorizontal>
#   			<TextWellPlateHorizontal>AD</TextWellPlateHorizontal>
#   			<TextWellPlateHorizontal>AE</TextWellPlateHorizontal>
#   			<TextWellPlateHorizontal>AF</TextWellPlateHorizontal>
#   			<TextWellPlateVertical>1</TextWellPlateVertical>
#   			<TextWellPlateVertical>2</TextWellPlateVertical>
#   			<TextWellPlateVertical>3</TextWellPlateVertical>
#   			<TextWellPlateVertical>4</TextWellPlateVertical>
#   			<TextWellPlateVertical>5</TextWellPlateVertical>
#   			<TextWellPlateVertical>6</TextWellPlateVertical>
#   			<TextWellPlateVertical>7</TextWellPlateVertical>
#   			<TextWellPlateVertical>8</TextWellPlateVertical>
#   			<TextWellPlateVertical>9</TextWellPlateVertical>
#   			<TextWellPlateVertical>10</TextWellPlateVertical>
#   			<TextWellPlateVertical>11</TextWellPlateVertical>
#   			<TextWellPlateVertical>12</TextWellPlateVertical>
#   			<TextWellPlateVertical>13</TextWellPlateVertical>
#   			<TextWellPlateVertical>14</TextWellPlateVertical>
#   			<TextWellPlateVertical>15</TextWellPlateVertical>
#   			<TextWellPlateVertical>16</TextWellPlateVertical>
#   			<TextWellPlateVertical>17</TextWellPlateVertical>
#   			<TextWellPlateVertical>18</TextWellPlateVertical>
#   			<TextWellPlateVertical>19</TextWellPlateVertical>
#   			<TextWellPlateVertical>20</TextWellPlateVertical>
#   			<TextWellPlateVertical>21</TextWellPlateVertical>
#   			<TextWellPlateVertical>22</TextWellPlateVertical>
#   			<TextWellPlateVertical>23</TextWellPlateVertical>
#   			<TextWellPlateVertical>24</TextWellPlateVertical>
#   			<TextWellPlateVertical>25</TextWellPlateVertical>
#   			<TextWellPlateVertical>26</TextWellPlateVertical>
#   			<TextWellPlateVertical>27</TextWellPlateVertical>
#   			<TextWellPlateVertical>28</TextWellPlateVertical>
#   			<TextWellPlateVertical>29</TextWellPlateVertical>
#   			<TextWellPlateVertical>30</TextWellPlateVertical>
#   			<TextWellPlateVertical>31</TextWellPlateVertical>
#   			<TextWellPlateVertical>32</TextWellPlateVertical>
#   			<TextWellPlateVertical>33</TextWellPlateVertical>
#   			<TextWellPlateVertical>34</TextWellPlateVertical>
#   			<TextWellPlateVertical>35</TextWellPlateVertical>
#   			<TextWellPlateVertical>36</TextWellPlateVertical>
#   			<TextWellPlateVertical>37</TextWellPlateVertical>
#   			<TextWellPlateVertical>38</TextWellPlateVertical>
#   			<TextWellPlateVertical>39</TextWellPlateVertical>
#   			<TextWellPlateVertical>40</TextWellPlateVertical>
#   			<TextWellPlateVertical>41</TextWellPlateVertical>
#   			<TextWellPlateVertical>42</TextWellPlateVertical>
#   			<TextWellPlateVertical>43</TextWellPlateVertical>
#   			<TextWellPlateVertical>44</TextWellPlateVertical>
#   			<TextWellPlateVertical>45</TextWellPlateVertical>
#   			<TextWellPlateVertical>46</TextWellPlateVertical>
#   			<TextWellPlateVertical>47</TextWellPlateVertical>
#   			<TextWellPlateVertical>48</TextWellPlateVertical>
#   			<TextWellPlateVertical>49</TextWellPlateVertical>
#   			<TextWellPlateVertical>50</TextWellPlateVertical>
#   			<TextWellPlateVertical>51</TextWellPlateVertical>
#   			<TextWellPlateVertical>52</TextWellPlateVertical>
#   			<TextWellPlateVertical>53</TextWellPlateVertical>
#   			<TextWellPlateVertical>54</TextWellPlateVertical>
#   			<TextWellPlateVertical>55</TextWellPlateVertical>
#   			<TextWellPlateVertical>56</TextWellPlateVertical>
#   			<TextWellPlateVertical>57</TextWellPlateVertical>
#   			<TextWellPlateVertical>58</TextWellPlateVertical>
#   			<TextFillColorTextBox>A5A6A1</TextFillColorTextBox>
#   			<TextColorTextBox>23272E</TextColorTextBox>
#   			<EnableTextBox>false</EnableTextBox>
#   			<TextFontSize>12</TextFontSize>
#   			<DrawText>true</DrawText>
#   			<FlipText>false</FlipText>
#   			<AgendaLineDistance>30</AgendaLineDistance>
#   			<AgendaTextDistance>20</AgendaTextDistance>
#   			<AgendaBulletWidth>15</AgendaBulletWidth>
#   			<AgendaTextWidth>120</AgendaTextWidth>
#   			<AgendaXPosition>20</AgendaXPosition>
#   			<AgendaYPosition>0</AgendaYPosition>
#   			<AgendaTextColor>D4D3CC</AgendaTextColor>
#   			<AgendaFontSize>10</AgendaFontSize>
#   			<EnableAgenda>true</EnableAgenda>
#   			<DescriptionTextColor>000000</DescriptionTextColor>
#   			<DescriptionFontSize>10</DescriptionFontSize>
#   			<EnableDescription>true</EnableDescription>
#   			<Description>{ScanningTemplate}movement diff </Description>
#   			<BlinkerColorOff>006400</BlinkerColorOff>
#   			<BlinkerColorOn>00FF00</BlinkerColorOn>
#   			<BlinkerIntervall>500</BlinkerIntervall>
#   			<ColorDesign>LeicaDesign</ColorDesign>
#   			<ScanFieldStageStartPositionX>40002</ScanFieldStageStartPositionX>
#   			<ScanFieldStageStartPositionY>31025</ScanFieldStageStartPositionY>
#   			<ScanFieldStageDistanceX>450</ScanFieldStageDistanceX>
#   			<ScanFieldStageDistanceY>450</ScanFieldStageDistanceY>
#   			<ScanWellStageDistanceX>1750</ScanWellStageDistanceX>
#   			<ScanWellStageDistanceY>1750</ScanWellStageDistanceY>
#   			<ScanFieldArrayOffsetZ>0</ScanFieldArrayOffsetZ>
#   			<AutoFocusPattern>IsStandardAFScanFieldPattern</AutoFocusPattern>
#   			<AutoFocusColor>FF7F50</AutoFocusColor>
#   			<AutoFocusScanFieldInterval>2</AutoFocusScanFieldInterval>
#   			<AutoFocusScanRange>80</AutoFocusScanRange>
#   			<AutoFocusSliceCount>20</AutoFocusSliceCount>
#   			<EnableAutoFocusDZOffset>false</EnableAutoFocusDZOffset>
#   			<AutoFocusDzOffset>-0</AutoFocusDzOffset>
#   			<MatrixJobPattern/>
#   			<ZUseMode>1</ZUseMode>
#   			<DriftRepeatInterval>1</DriftRepeatInterval>
#   			<ShowDriftCompensationFields>true</ShowDriftCompensationFields>
#   			<PetriDishVisualisation>false</PetriDishVisualisation>
#   			<SelectedAutofocusJobName>AF Job</SelectedAutofocusJobName>
#   			<SelectedTrackJobName>Job 2</SelectedTrackJobName>
#   			<IsOverlapInPercentSelected>true</IsOverlapInPercentSelected>
#   			<MosaicOverlapInPercent>10</MosaicOverlapInPercent>
#   			<MosaicOverlapInMicronsX>0</MosaicOverlapInMicronsX>
#   			<MosaicOverlapInMicronsY>0</MosaicOverlapInMicronsY>
#   			<CanDoRealTime3D>false</CanDoRealTime3D>
#   			<AutoRotate3D>false</AutoRotate3D>
#   		</Properties>
#   	</ScanningTemplate>
#   	<ScanFieldArray>
#   		<ScanFieldData AFJobId="0" AFScanRange="0" AFScore="0" AFSliceCount="0" Description="MatrixScreener" DriftScanRange="0" DriftSliceCount="0" Enabled="true" FieldX="1" FieldY="1" Indicator="IsStandardScanField" IsAutofocusScanField="false" IsDriftCompensationField="false" IsIndividualAutofocusScanField="false" IsMosaicCalibrationField="false" IsPumpScanField="false" IsTrackingField="false" JobAssigned="true" JobId="8" JobName="Job 2" LabelX="A" LabelY="1" PumpDelay="1000" PumpTime="1000" Selected="false" Shape="IsRectangle" SlideNo="0" State="IsActive" WellX="1" WellY="1">
# - 			<FieldXCoordinate>0.040102</FieldXCoordinate>
# ? 			                        ^^
#
# + 			<FieldXCoordinate>0.040001999999999996</FieldXCoordinate>
# ? 			                       ++ ^^^^^^^^^^^^
#
# - 			<FieldYCoordinate>0.030924999999999998</FieldYCoordinate>
# ? 			                       -             ^
#
# + 			<FieldYCoordinate>0.031024999999999997</FieldYCoordinate>
# ? 			                      +              ^
#
#   			<FieldZCoordinate>-2.3841880645312022E-10</FieldZCoordinate>
#   			<FieldScanSlices>0</FieldScanSlices>
#   			<FieldScanRange>0</FieldScanRange>
#   			<FieldRotation>0</FieldRotation>
#   		</ScanFieldData>
#   		<ScanFieldData AFJobId="0" AFScanRange="0" AFScore="0" AFSliceCount="0" Description="MatrixScreener" DriftScanRange="0" DriftSliceCount="0" Enabled="true" FieldX="1" FieldY="2" Indicator="IsStandardScanField" IsAutofocusScanField="false" IsDriftCompensationField="false" IsIndividualAutofocusScanField="false" IsMosaicCalibrationField="false" IsPumpScanField="false" IsTrackingField="false" JobAssigned="true" JobId="8" JobName="Job 2" LabelX="A" LabelY="1" PumpDelay="1000" PumpTime="1000" Selected="false" Shape="IsRectangle" SlideNo="0" State="IsActive" WellX="1" WellY="1">
# - 			<FieldXCoordinate>0.040102</FieldXCoordinate>
# ? 			                        ^^
#
# + 			<FieldXCoordinate>0.040001999999999996</FieldXCoordinate>
# ? 			                       ++ ^^^^^^^^^^^^
#
# - 			<FieldYCoordinate>0.031374999999999993</FieldYCoordinate>
# ? 			                       ^             ^
#
# + 			<FieldYCoordinate>0.031474999999999996</FieldYCoordinate>
# ? 			                       ^             ^
#
#   			<FieldZCoordinate>-2.3841880645312022E-10</FieldZCoordinate>
#   			<FieldScanSlices>0</FieldScanSlices>
#   			<FieldScanRange>0</FieldScanRange>
#   			<FieldRotation>0</FieldRotation>
#   		</ScanFieldData>
#   		<ScanFieldData AFJobId="0" AFScanRange="0" AFScore="0" AFSliceCount="0" Description="MatrixScreener" DriftScanRange="0" DriftSliceCount="0" Enabled="true" FieldX="2" FieldY="1" Indicator="IsStandardScanField" IsAutofocusScanField="false" IsDriftCompensationField="false" IsIndividualAutofocusScanField="false" IsMosaicCalibrationField="false" IsPumpScanField="false" IsTrackingField="false" JobAssigned="true" JobId="8" JobName="Job 2" LabelX="A" LabelY="1" PumpDelay="1000" PumpTime="1000" Selected="false" Shape="IsRectangle" SlideNo="0" State="IsActive" WellX="1" WellY="1">
# - 			<FieldXCoordinate>0.040552</FieldXCoordinate>
# ? 			                         -
#
# + 			<FieldXCoordinate>0.040451999999999995</FieldXCoordinate>
# ? 			                       + ++++++++++++
#
# - 			<FieldYCoordinate>0.030924999999999998</FieldYCoordinate>
# ? 			                       -             ^
#
# + 			<FieldYCoordinate>0.031024999999999997</FieldYCoordinate>
# ? 			                      +              ^
#
#   			<FieldZCoordinate>-2.3841880645312022E-10</FieldZCoordinate>
#   			<FieldScanSlices>0</FieldScanSlices>
#   			<FieldScanRange>0</FieldScanRange>
#   			<FieldRotation>0</FieldRotation>
#   		</ScanFieldData>
#   		<ScanFieldData AFJobId="0" AFScanRange="0" AFScore="0" AFSliceCount="0" Description="MatrixScreener" DriftScanRange="0" DriftSliceCount="0" Enabled="true" FieldX="2" FieldY="2" Indicator="IsStandardScanField" IsAutofocusScanField="false" IsDriftCompensationField="false" IsIndividualAutofocusScanField="false" IsMosaicCalibrationField="false" IsPumpScanField="false" IsTrackingField="false" JobAssigned="true" JobId="8" JobName="Job 2" LabelX="A" LabelY="1" PumpDelay="1000" PumpTime="1000" Selected="false" Shape="IsRectangle" SlideNo="0" State="IsActive" WellX="1" WellY="1">
# - 			<FieldXCoordinate>0.040552</FieldXCoordinate>
# ? 			                         -
#
# + 			<FieldXCoordinate>0.040451999999999995</FieldXCoordinate>
# ? 			                       + ++++++++++++
#
# - 			<FieldYCoordinate>0.031374999999999993</FieldYCoordinate>
# ? 			                       ^             ^
#
# + 			<FieldYCoordinate>0.031474999999999996</FieldYCoordinate>
# ? 			                       ^             ^
#
#   			<FieldZCoordinate>-2.3841880645312022E-10</FieldZCoordinate>
#   			<FieldScanSlices>0</FieldScanSlices>
#   			<FieldScanRange>0</FieldScanRange>
#   			<FieldRotation>0</FieldRotation>
#   		</ScanFieldData>
#   		<ScanFieldData AFJobId="0" AFScanRange="0" AFScore="0" AFSliceCount="0" Description="MatrixScreener" DriftScanRange="0" DriftSliceCount="0" Enabled="true" FieldX="1" FieldY="1" Indicator="IsStandardScanField" IsAutofocusScanField="false" IsDriftCompensationField="false" IsIndividualAutofocusScanField="false" IsMosaicCalibrationField="false" IsPumpScanField="false" IsTrackingField="false" JobAssigned="true" JobId="8" JobName="Job 2" LabelX="A" LabelY="2" PumpDelay="1000" PumpTime="1000" Selected="false" Shape="IsRectangle" SlideNo="0" State="IsActive" WellX="1" WellY="2">
#   			<FieldXCoordinate>0.040001999999999996</FieldXCoordinate>
#   			<FieldYCoordinate>0.032775</FieldYCoordinate>
#   			<FieldZCoordinate>-2.3841880645312022E-10</FieldZCoordinate>
#   			<FieldScanSlices>0</FieldScanSlices>
#   			<FieldScanRange>0</FieldScanRange>
#   			<FieldRotation>0</FieldRotation>
#   		</ScanFieldData>
#   		<ScanFieldData AFJobId="0" AFScanRange="0" AFScore="0" AFSliceCount="0" Description="MatrixScreener" DriftScanRange="0" DriftSliceCount="0" Enabled="true" FieldX="1" FieldY="2" Indicator="IsStandardScanField" IsAutofocusScanField="false" IsDriftCompensationField="false" IsIndividualAutofocusScanField="false" IsMosaicCalibrationField="false" IsPumpScanField="false" IsTrackingField="false" JobAssigned="true" JobId="8" JobName="Job 2" LabelX="A" LabelY="2" PumpDelay="1000" PumpTime="1000" Selected="false" Shape="IsRectangle" SlideNo="0" State="IsActive" WellX="1" WellY="2">
#   			<FieldXCoordinate>0.040001999999999996</FieldXCoordinate>
#   			<FieldYCoordinate>0.033225</FieldYCoordinate>
#   			<FieldZCoordinate>-2.3841880645312022E-10</FieldZCoordinate>
#   			<FieldScanSlices>0</FieldScanSlices>
#   			<FieldScanRange>0</FieldScanRange>
#   			<FieldRotation>0</FieldRotation>
#   		</ScanFieldData>
#   		<ScanFieldData AFJobId="0" AFScanRange="0" AFScore="0" AFSliceCount="0" Description="MatrixScreener" DriftScanRange="0" DriftSliceCount="0" Enabled="true" FieldX="2" FieldY="1" Indicator="IsStandardScanField" IsAutofocusScanField="false" IsDriftCompensationField="false" IsIndividualAutofocusScanField="false" IsMosaicCalibrationField="false" IsPumpScanField="false" IsTrackingField="false" JobAssigned="true" JobId="8" JobName="Job 2" LabelX="A" LabelY="2" PumpDelay="1000" PumpTime="1000" Selected="false" Shape="IsRectangle" SlideNo="0" State="IsActive" WellX="1" WellY="2">
#   			<FieldXCoordinate>0.040451999999999995</FieldXCoordinate>
#   			<FieldYCoordinate>0.032775</FieldYCoordinate>
#   			<FieldZCoordinate>-2.3841880645312022E-10</FieldZCoordinate>
#   			<FieldScanSlices>0</FieldScanSlices>
#   			<FieldScanRange>0</FieldScanRange>
#   			<FieldRotation>0</FieldRotation>
#   		</ScanFieldData>
#   		<ScanFieldData AFJobId="0" AFScanRange="0" AFScore="0" AFSliceCount="0" Description="MatrixScreener" DriftScanRange="0" DriftSliceCount="0" Enabled="true" FieldX="2" FieldY="2" Indicator="IsStandardScanField" IsAutofocusScanField="false" IsDriftCompensationField="false" IsIndividualAutofocusScanField="false" IsMosaicCalibrationField="false" IsPumpScanField="false" IsTrackingField="false" JobAssigned="true" JobId="8" JobName="Job 2" LabelX="A" LabelY="2" PumpDelay="1000" PumpTime="1000" Selected="false" Shape="IsRectangle" SlideNo="0" State="IsActive" WellX="1" WellY="2">
#   			<FieldXCoordinate>0.040451999999999995</FieldXCoordinate>
#   			<FieldYCoordinate>0.033225</FieldYCoordinate>
#   			<FieldZCoordinate>-2.3841880645312022E-10</FieldZCoordinate>
#   			<FieldScanSlices>0</FieldScanSlices>
#   			<FieldScanRange>0</FieldScanRange>
#   			<FieldRotation>0</FieldRotation>
#   		</ScanFieldData>
#   		<ScanFieldData AFJobId="0" AFScanRange="0" AFScore="0" AFSliceCount="0" Description="MatrixScreener" DriftScanRange="0" DriftSliceCount="0" Enabled="true" FieldX="1" FieldY="1" Indicator="IsStandardScanField" IsAutofocusScanField="false" IsDriftCompensationField="false" IsIndividualAutofocusScanField="false" IsMosaicCalibrationField="false" IsPumpScanField="false" IsTrackingField="false" JobAssigned="true" JobId="8" JobName="Job 2" LabelX="B" LabelY="1" PumpDelay="1000" PumpTime="1000" Selected="false" Shape="IsRectangle" SlideNo="0" State="IsActive" WellX="2" WellY="1">
#   			<FieldXCoordinate>0.041752</FieldXCoordinate>
#   			<FieldYCoordinate>0.031024999999999997</FieldYCoordinate>
#   			<FieldZCoordinate>-2.3841880645312022E-10</FieldZCoordinate>
#   			<FieldScanSlices>0</FieldScanSlices>
#   			<FieldScanRange>0</FieldScanRange>
#   			<FieldRotation>0</FieldRotation>
#   		</ScanFieldData>
#   		<ScanFieldData AFJobId="0" AFScanRange="0" AFScore="0" AFSliceCount="0" Description="MatrixScreener" DriftScanRange="0" DriftSliceCount="0" Enabled="true" FieldX="1" FieldY="2" Indicator="IsStandardScanField" IsAutofocusScanField="false" IsDriftCompensationField="false" IsIndividualAutofocusScanField="false" IsMosaicCalibrationField="false" IsPumpScanField="false" IsTrackingField="false" JobAssigned="true" JobId="8" JobName="Job 2" LabelX="B" LabelY="1" PumpDelay="1000" PumpTime="1000" Selected="false" Shape="IsRectangle" SlideNo="0" State="IsActive" WellX="2" WellY="1">
#   			<FieldXCoordinate>0.041752</FieldXCoordinate>
#   			<FieldYCoordinate>0.031474999999999996</FieldYCoordinate>
#   			<FieldZCoordinate>-2.3841880645312022E-10</FieldZCoordinate>
#   			<FieldScanSlices>0</FieldScanSlices>
#   			<FieldScanRange>0</FieldScanRange>
#   			<FieldRotation>0</FieldRotation>
#   		</ScanFieldData>
#   		<ScanFieldData AFJobId="0" AFScanRange="0" AFScore="0" AFSliceCount="0" Description="MatrixScreener" DriftScanRange="0" DriftSliceCount="0" Enabled="true" FieldX="2" FieldY="1" Indicator="IsStandardScanField" IsAutofocusScanField="false" IsDriftCompensationField="false" IsIndividualAutofocusScanField="false" IsMosaicCalibrationField="false" IsPumpScanField="false" IsTrackingField="false" JobAssigned="true" JobId="8" JobName="Job 2" LabelX="B" LabelY="1" PumpDelay="1000" PumpTime="1000" Selected="false" Shape="IsRectangle" SlideNo="0" State="IsActive" WellX="2" WellY="1">
#   			<FieldXCoordinate>0.042201999999999996</FieldXCoordinate>
#   			<FieldYCoordinate>0.031024999999999997</FieldYCoordinate>
#   			<FieldZCoordinate>-2.3841880645312022E-10</FieldZCoordinate>
#   			<FieldScanSlices>0</FieldScanSlices>
#   			<FieldScanRange>0</FieldScanRange>
#   			<FieldRotation>0</FieldRotation>
#   		</ScanFieldData>
#   		<ScanFieldData AFJobId="0" AFScanRange="0" AFScore="0" AFSliceCount="0" Description="MatrixScreener" DriftScanRange="0" DriftSliceCount="0" Enabled="true" FieldX="2" FieldY="2" Indicator="IsStandardScanField" IsAutofocusScanField="false" IsDriftCompensationField="false" IsIndividualAutofocusScanField="false" IsMosaicCalibrationField="false" IsPumpScanField="false" IsTrackingField="false" JobAssigned="true" JobId="8" JobName="Job 2" LabelX="B" LabelY="1" PumpDelay="1000" PumpTime="1000" Selected="false" Shape="IsRectangle" SlideNo="0" State="IsActive" WellX="2" WellY="1">
#   			<FieldXCoordinate>0.042201999999999996</FieldXCoordinate>
#   			<FieldYCoordinate>0.031474999999999996</FieldYCoordinate>
#   			<FieldZCoordinate>-2.3841880645312022E-10</FieldZCoordinate>
#   			<FieldScanSlices>0</FieldScanSlices>
#   			<FieldScanRange>0</FieldScanRange>
#   			<FieldRotation>0</FieldRotation>
#   		</ScanFieldData>
#   		<ScanFieldData AFJobId="0" AFScanRange="0" AFScore="0" AFSliceCount="0" Description="MatrixScreener" DriftScanRange="0" DriftSliceCount="0" Enabled="true" FieldX="1" FieldY="1" Indicator="IsStandardScanField" IsAutofocusScanField="false" IsDriftCompensationField="false" IsIndividualAutofocusScanField="false" IsMosaicCalibrationField="false" IsPumpScanField="false" IsTrackingField="false" JobAssigned="true" JobId="8" JobName="Job 2" LabelX="B" LabelY="2" PumpDelay="1000" PumpTime="1000" Selected="false" Shape="IsRectangle" SlideNo="0" State="IsActive" WellX="2" WellY="2">
# - 			<FieldXCoordinate>0.041752</FieldXCoordinate>
# ? 			                       ^ ^
#
# + 			<FieldXCoordinate>0.041651999999999995</FieldXCoordinate>
# ? 			                       ^ ^^^^^^^^^^^^^
#
# - 			<FieldYCoordinate>0.032775</FieldYCoordinate>
# ? 			                       ^
#
# + 			<FieldYCoordinate>0.032875</FieldYCoordinate>
# ? 			                       ^
#
#   			<FieldZCoordinate>-2.3841880645312022E-10</FieldZCoordinate>
#   			<FieldScanSlices>0</FieldScanSlices>
#   			<FieldScanRange>0</FieldScanRange>
#   			<FieldRotation>0</FieldRotation>
#   		</ScanFieldData>
#   		<ScanFieldData AFJobId="0" AFScanRange="0" AFScore="0" AFSliceCount="0" Description="MatrixScreener" DriftScanRange="0" DriftSliceCount="0" Enabled="true" FieldX="1" FieldY="2" Indicator="IsStandardScanField" IsAutofocusScanField="false" IsDriftCompensationField="false" IsIndividualAutofocusScanField="false" IsMosaicCalibrationField="false" IsPumpScanField="false" IsTrackingField="false" JobAssigned="true" JobId="8" JobName="Job 2" LabelX="B" LabelY="2" PumpDelay="1000" PumpTime="1000" Selected="false" Shape="IsRectangle" SlideNo="0" State="IsActive" WellX="2" WellY="2">
# - 			<FieldXCoordinate>0.041752</FieldXCoordinate>
# ? 			                       ^ ^
#
# + 			<FieldXCoordinate>0.041651999999999995</FieldXCoordinate>
# ? 			                       ^ ^^^^^^^^^^^^^
#
# - 			<FieldYCoordinate>0.033225</FieldYCoordinate>
# ? 			                       ^
#
# + 			<FieldYCoordinate>0.033325</FieldYCoordinate>
# ? 			                       ^
#
#   			<FieldZCoordinate>-2.3841880645312022E-10</FieldZCoordinate>
#   			<FieldScanSlices>0</FieldScanSlices>
#   			<FieldScanRange>0</FieldScanRange>
#   			<FieldRotation>0</FieldRotation>
#   		</ScanFieldData>
#   		<ScanFieldData AFJobId="0" AFScanRange="0" AFScore="0" AFSliceCount="0" Description="MatrixScreener" DriftScanRange="0" DriftSliceCount="0" Enabled="true" FieldX="2" FieldY="1" Indicator="IsStandardScanField" IsAutofocusScanField="false" IsDriftCompensationField="false" IsIndividualAutofocusScanField="false" IsMosaicCalibrationField="false" IsPumpScanField="false" IsTrackingField="false" JobAssigned="true" JobId="8" JobName="Job 2" LabelX="B" LabelY="2" PumpDelay="1000" PumpTime="1000" Selected="false" Shape="IsRectangle" SlideNo="0" State="IsActive" WellX="2" WellY="2">
# - 			<FieldXCoordinate>0.042201999999999996</FieldXCoordinate>
# ? 			                       ^             ^
#
# + 			<FieldXCoordinate>0.042101999999999994</FieldXCoordinate>
# ? 			                       ^             ^
#
# - 			<FieldYCoordinate>0.032775</FieldYCoordinate>
# ? 			                       ^
#
# + 			<FieldYCoordinate>0.032875</FieldYCoordinate>
# ? 			                       ^
#
#   			<FieldZCoordinate>-2.3841880645312022E-10</FieldZCoordinate>
#   			<FieldScanSlices>0</FieldScanSlices>
#   			<FieldScanRange>0</FieldScanRange>
#   			<FieldRotation>0</FieldRotation>
#   		</ScanFieldData>
#   		<ScanFieldData AFJobId="0" AFScanRange="0" AFScore="0" AFSliceCount="0" Description="MatrixScreener" DriftScanRange="0" DriftSliceCount="0" Enabled="true" FieldX="2" FieldY="2" Indicator="IsStandardScanField" IsAutofocusScanField="false" IsDriftCompensationField="false" IsIndividualAutofocusScanField="false" IsMosaicCalibrationField="false" IsPumpScanField="false" IsTrackingField="false" JobAssigned="true" JobId="8" JobName="Job 2" LabelX="B" LabelY="2" PumpDelay="1000" PumpTime="1000" Selected="false" Shape="IsRectangle" SlideNo="0" State="IsActive" WellX="2" WellY="2">
# - 			<FieldXCoordinate>0.042201999999999996</FieldXCoordinate>
# ? 			                       ^             ^
#
# + 			<FieldXCoordinate>0.042101999999999994</FieldXCoordinate>
# ? 			                       ^             ^
#
# - 			<FieldYCoordinate>0.033225</FieldYCoordinate>
# ? 			                       ^
#
# + 			<FieldYCoordinate>0.033325</FieldYCoordinate>
# ? 			                       ^
#
#   			<FieldZCoordinate>-2.3841880645312022E-10</FieldZCoordinate>
#   			<FieldScanSlices>0</FieldScanSlices>
#   			<FieldScanRange>0</FieldScanRange>
#   			<FieldRotation>0</FieldRotation>
#   		</ScanFieldData>
#   	</ScanFieldArray>
#   	<ScanWellArray>
# - 		<ScanWellData FieldXStartCoordinate="0.040102" FieldYStartCoordinate="0.030924999999999998" FieldZCoordinate="-2.3841880645312022E-10" Indicator="IsStandardScanWell" MosaicFlipImage="false" MosaicImageEndX="0.04000241115938" MosaicImageEndY="0.031025667708599998" MosaicImageHeight="0" MosaicImageStartX="0.04000241115938" MosaicImageStartY="0.031025667708599998" MosaicImageWidth="0" MosaicScanImageRotation="0" MosaicSingleImageHeight="0.00058125" MosaicSingleImageWidth="0.00058125" MosaicTileImageOverlapX="0" MosaicTileImageOverlapY="0" ScanFieldDiameter="0" SlideNo="1" WellX="1" WellXOffset="0" WellY="1" WellYOffset="0" XCountOfFields="2" YCountOfFields="2"/>
# ? 		                                          ^^^                             ^^^^^^^^^^^^^^^^
#
# + 		<ScanWellData FieldXStartCoordinate="0.040001999999999996" FieldYStartCoordinate="0.031024999999999997" FieldZCoordinate="-2.3841880645312022E-10" Indicator="IsStandardScanWell" MosaicFlipImage="false" MosaicImageEndX="0.04000241115938" MosaicImageEndY="0.031025667708599998" MosaicImageHeight="0" MosaicImageStartX="0.04000241115938" MosaicImageStartY="0.031025667708599998" MosaicImageWidth="0" MosaicScanImageRotation="0" MosaicSingleImageHeight="0.00058125" MosaicSingleImageWidth="0.00058125" MosaicTileImageOverlapX="0" MosaicTileImageOverlapY="0" ScanFieldDiameter="0" SlideNo="1" WellX="1" WellXOffset="0" WellY="1" WellYOffset="0" XCountOfFields="2" YCountOfFields="2"/>
# ? 		                                          ^^^^^^^^^^^^^^^                             ^^^^^^^^^^^^^^^^
#
#   		<ScanWellData FieldXStartCoordinate="0.040001999999999996" FieldYStartCoordinate="0.032775" FieldZCoordinate="-2.3841880645312022E-10" Indicator="IsStandardScanWell" MosaicFlipImage="false" MosaicImageEndX="0.04000241115938" MosaicImageEndY="0.031025667708599998" MosaicImageHeight="0" MosaicImageStartX="0.04000241115938" MosaicImageStartY="0.031025667708599998" MosaicImageWidth="0" MosaicScanImageRotation="0" MosaicSingleImageHeight="0.00058125" MosaicSingleImageWidth="0.00058125" MosaicTileImageOverlapX="0" MosaicTileImageOverlapY="0" ScanFieldDiameter="0" SlideNo="1" WellX="1" WellXOffset="0" WellY="2" WellYOffset="0" XCountOfFields="2" YCountOfFields="2"/>
#   		<ScanWellData FieldXStartCoordinate="0.041752" FieldYStartCoordinate="0.031024999999999997" FieldZCoordinate="-2.3841880645312022E-10" Indicator="IsStandardScanWell" MosaicFlipImage="false" MosaicImageEndX="0.04000241115938" MosaicImageEndY="0.031025667708599998" MosaicImageHeight="0" MosaicImageStartX="0.04000241115938" MosaicImageStartY="0.031025667708599998" MosaicImageWidth="0" MosaicScanImageRotation="0" MosaicSingleImageHeight="0.00058125" MosaicSingleImageWidth="0.00058125" MosaicTileImageOverlapX="0" MosaicTileImageOverlapY="0" ScanFieldDiameter="0" SlideNo="1" WellX="2" WellXOffset="0" WellY="1" WellYOffset="0" XCountOfFields="2" YCountOfFields="2"/>
# - 		<ScanWellData FieldXStartCoordinate="0.041752" FieldYStartCoordinate="0.032775" FieldZCoordinate="-2.3841880645312022E-10" Indicator="IsStandardScanWell" MosaicFlipImage="false" MosaicImageEndX="0.04000241115938" MosaicImageEndY="0.031025667708599998" MosaicImageHeight="0" MosaicImageStartX="0.04000241115938" MosaicImageStartY="0.031025667708599998" MosaicImageWidth="0" MosaicScanImageRotation="0" MosaicSingleImageHeight="0.00058125" MosaicSingleImageWidth="0.00058125" MosaicTileImageOverlapX="0" MosaicTileImageOverlapY="0" ScanFieldDiameter="0" SlideNo="1" WellX="2" WellXOffset="0" WellY="2" WellYOffset="0" XCountOfFields="2" YCountOfFields="2"/>
# ? 		                                          ^^^                              ^
#
# + 		<ScanWellData FieldXStartCoordinate="0.041651999999999995" FieldYStartCoordinate="0.032875" FieldZCoordinate="-2.3841880645312022E-10" Indicator="IsStandardScanWell" MosaicFlipImage="false" MosaicImageEndX="0.04000241115938" MosaicImageEndY="0.031025667708599998" MosaicImageHeight="0" MosaicImageStartX="0.04000241115938" MosaicImageStartY="0.031025667708599998" MosaicImageWidth="0" MosaicScanImageRotation="0" MosaicSingleImageHeight="0.00058125" MosaicSingleImageWidth="0.00058125" MosaicTileImageOverlapX="0" MosaicTileImageOverlapY="0" ScanFieldDiameter="0" SlideNo="1" WellX="2" WellXOffset="0" WellY="2" WellYOffset="0" XCountOfFields="2" YCountOfFields="2"/>
# ? 		                                          ^^^^^^^^^^^^^^^                              ^
#
#   	</ScanWellArray>
#   </MatrixScreenerTemplate>
# Out:
# Overwriting diff.xml

# %% [markdown]
# # compare with editing of xml

# %%
def offset_well(xml_root, u, v, offset_x=0, offset_y=0, offset_z=0):
    "Offset a given well in a etree xml."
    
    # every ScanFieldData with attr WellX and WellY set to u,v
    # https://docs.python.org/3/library/xml.etree.elementtree.html#supported-xpath-syntax
    fields = xml_root.findall('.//ScanFieldData[@WellX="{}"][@WellY="{}"]'.format(u,v))
    # set field values
    for field in fields:
        X = field.find('FieldXCoordinate')
        Y = field.find('FieldYCoordinate')
        Z = field.find('FieldZCoordinate')

        x = float(X.text) + offset_x
        y = float(Y.text) + offset_y
        z = float(Z.text) + offset_z

        X.text = "%.19f" % x
        Y.text = "%.19f" % y
        Z.text = "%.19f" % z

    # set well start value
    well = xml_root.find('.//ScanWellData[@WellX="{}"][@WellY="{}"]'.format(u,v))
    
    x_start = float(well.attrib['FieldXStartCoordinate']) + offset_x
    y_start = float(well.attrib['FieldYStartCoordinate']) + offset_y
    z_start = float(well.attrib['FieldZCoordinate']) + offset_z
    
    well.attrib['FieldXStartCoordinate'] = "%.19f" % x_start
    well.attrib['FieldYStartCoordinate'] = "%.19f" % y_start
    well.attrib['FieldZCoordinate'] = "%.19f" % z_start

    return xml_root

# %%
import xml.etree.ElementTree as ET
from pprint import pprint
from bunch import Bunch

tree = ET.parse(file1)
root = tree.getroot()
offset_well(root, 1, 1, offset_x=1e-3)
# Out:
# <Element 'MatrixScreenerTemplate' at 0x1122a9f98>

# %%
new_name = file1[:-4] + '-edited.xml'
tree.write(new_name)

# %%
from os import path
from difflib import Differ

xml_orig = pretty_xml(file1)
xml_diff = pretty_xml(new_name)

compare = Differ().compare
diff = compare(xml_orig, xml_diff)
diff_str = "\n".join(diff)

# %load(diff_str)

# %%
  <?xml version="1.0" ?>
- <MatrixScreenerTemplate xmlns:xsd="http://www.w3.org/2001/XMLSchema" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance">
+ <MatrixScreenerTemplate>
  	<ScanningTemplate>
  		<Properties TotalAssignedJobs="16" TotalCountOfFields="16" TotalCountOfWells="4" UniqueJobCounter="1" Version="Version: 1.0.4.563 -- Build 08.08.2013">
  			<CurrentDate>Tuesday, January 13, 2015 | 10:42 AM</CurrentDate>
  			<EnableTrigger>false</EnableTrigger>
  			<TriggerRepeatCycles>1</TriggerRepeatCycles>
  			<DriftScanRange>5</DriftScanRange>
  			<DriftSliceCount>5</DriftSliceCount>
  			<EnableCAM>false</EnableCAM>
  			<ShowPumpFields>false</ShowPumpFields>
  			<EnablePump>false</EnablePump>
  			<PumpRepeatInterval>1</PumpRepeatInterval>
  			<PumpDelay>1000</PumpDelay>
  			<PumpTime>1000</PumpTime>
  			<EnableContextMenu>true</EnableContextMenu>
  			<ContextType>eMatrixContextStripe</ContextType>
  			<ScanningTemplateType>eIsMatrixTemplate</ScanningTemplateType>
  			<EnableTrackRemoveBoundaryObjects>false</EnableTrackRemoveBoundaryObjects>
  			<EnableTrackRemoveSmallObjects>false</EnableTrackRemoveSmallObjects>
  			<TrackAdaptiveThreshold>3</TrackAdaptiveThreshold>
  			<TrackSizeOfSmallObject>15</TrackSizeOfSmallObject>
  			<TrackRepeatInterval>1</TrackRepeatInterval>
  			<ShowTrackingFields>false</ShowTrackingFields>
  			<EnableTracking>false</EnableTracking>
  			<FixHeigthOfWell>50</FixHeigthOfWell>
  			<FixWidthOfWell>50</FixWidthOfWell>
  			<HoldSize>false</HoldSize>
  			<TextColorHeatMapDescription>808080</TextColorHeatMapDescription>
  			<DrawRandomizedTestHeatMap>false</DrawRandomizedTestHeatMap>
  			<EnableLUTBarInAgenda>false</EnableLUTBarInAgenda>
  			<LUTBarDescription>Focus Map</LUTBarDescription>
  			<LUTBarUpperText>-- 0.0 µm</LUTBarUpperText>
  			<LUTBarLowerText>-- 0.0 µm</LUTBarLowerText>
  			<LUTBarInHeight>144</LUTBarInHeight>
  			<EnableHeatMap>false</EnableHeatMap>
  			<HeatMapType>IsFocusMap</HeatMapType>
  			<HeatMapLUT>LUT_JET</HeatMapLUT>
  			<ColorWellOutlineSelected>00FF00</ColorWellOutlineSelected>
  			<ColorInActiveScanField>808080</ColorInActiveScanField>
  			<ColorScanFieldBoundary>000000</ColorScanFieldBoundary>
  			<ColorScanFieldForTracking>00FF00</ColorScanFieldForTracking>
  			<ColorCurrentScanField>00FF00</ColorCurrentScanField>
  			<ColorActiveScanField>404040</ColorActiveScanField>
  			<ColorWellOutline>000000</ColorWellOutline>
  			<ColorWellFilled>23272E</ColorWellFilled>
  			<EnableMultiSelection>false</EnableMultiSelection>
  			<ColorSelectedFields>9ACD32</ColorSelectedFields>
  			<EnableRubberBand>true</EnableRubberBand>
  			<ColorRubberBand>C00000</ColorRubberBand>
  			<ScanFieldEffectDesign>None</ScanFieldEffectDesign>
  			<ScanFieldShapeDesign>IsRectangle</ScanFieldShapeDesign>
  			<ScanFieldDistanceX>2</ScanFieldDistanceX>
  			<ScanFieldDistanceY>2</ScanFieldDistanceY>
  			<ScanFieldDiameter>40</ScanFieldDiameter>
  			<CountOfScanFieldsX>2</CountOfScanFieldsX>
  			<CountOfScanFieldsY>2</CountOfScanFieldsY>
  			<ExperimenTimeDistance>15</ExperimenTimeDistance>
  			<ExperimentLoopCount>1</ExperimentLoopCount>
  			<EnableIndividualWellScanFieldCount>false</EnableIndividualWellScanFieldCount>
  			<DrawWellOutlineIfSelected>false</DrawWellOutlineIfSelected>
  			<DrawWellOutline>true</DrawWellOutline>
  			<WellsDistanceX>42</WellsDistanceX>
  			<WellsDistanceY>42</WellsDistanceY>
  			<CountOfWellsX>2</CountOfWellsX>
  			<CountOfWellsY>2</CountOfWellsY>
  			<TextColorWellplateDescription>808080</TextColorWellplateDescription>
  			<TextWellPlateHorizontal>A</TextWellPlateHorizontal>
  			<TextWellPlateHorizontal>B</TextWellPlateHorizontal>
  			<TextWellPlateHorizontal>C</TextWellPlateHorizontal>
  			<TextWellPlateHorizontal>D</TextWellPlateHorizontal>
  			<TextWellPlateHorizontal>E</TextWellPlateHorizontal>
  			<TextWellPlateHorizontal>F</TextWellPlateHorizontal>
  			<TextWellPlateHorizontal>G</TextWellPlateHorizontal>
  			<TextWellPlateHorizontal>H</TextWellPlateHorizontal>
  			<TextWellPlateHorizontal>I</TextWellPlateHorizontal>
  			<TextWellPlateHorizontal>J</TextWellPlateHorizontal>
  			<TextWellPlateHorizontal>K</TextWellPlateHorizontal>
  			<TextWellPlateHorizontal>L</TextWellPlateHorizontal>
  			<TextWellPlateHorizontal>M</TextWellPlateHorizontal>
  			<TextWellPlateHorizontal>N</TextWellPlateHorizontal>
  			<TextWellPlateHorizontal>O</TextWellPlateHorizontal>
  			<TextWellPlateHorizontal>P</TextWellPlateHorizontal>
  			<TextWellPlateHorizontal>Q</TextWellPlateHorizontal>
  			<TextWellPlateHorizontal>R</TextWellPlateHorizontal>
  			<TextWellPlateHorizontal>S</TextWellPlateHorizontal>
  			<TextWellPlateHorizontal>T</TextWellPlateHorizontal>
  			<TextWellPlateHorizontal>U</TextWellPlateHorizontal>
  			<TextWellPlateHorizontal>V</TextWellPlateHorizontal>
  			<TextWellPlateHorizontal>W</TextWellPlateHorizontal>
  			<TextWellPlateHorizontal>X</TextWellPlateHorizontal>
  			<TextWellPlateHorizontal>Y</TextWellPlateHorizontal>
  			<TextWellPlateHorizontal>Z</TextWellPlateHorizontal>
  			<TextWellPlateHorizontal>AA</TextWellPlateHorizontal>
  			<TextWellPlateHorizontal>BB</TextWellPlateHorizontal>
  			<TextWellPlateHorizontal>CC</TextWellPlateHorizontal>
  			<TextWellPlateHorizontal>DD</TextWellPlateHorizontal>
  			<TextWellPlateHorizontal>EE</TextWellPlateHorizontal>
  			<TextWellPlateHorizontal>FF</TextWellPlateHorizontal>
  			<TextWellPlateHorizontal>AB</TextWellPlateHorizontal>
  			<TextWellPlateHorizontal>AC</TextWellPlateHorizontal>
  			<TextWellPlateHorizontal>AD</TextWellPlateHorizontal>
  			<TextWellPlateHorizontal>AE</TextWellPlateHorizontal>
  			<TextWellPlateHorizontal>AF</TextWellPlateHorizontal>
  			<TextWellPlateVertical>1</TextWellPlateVertical>
  			<TextWellPlateVertical>2</TextWellPlateVertical>
  			<TextWellPlateVertical>3</TextWellPlateVertical>
  			<TextWellPlateVertical>4</TextWellPlateVertical>
  			<TextWellPlateVertical>5</TextWellPlateVertical>
  			<TextWellPlateVertical>6</TextWellPlateVertical>
  			<TextWellPlateVertical>7</TextWellPlateVertical>
  			<TextWellPlateVertical>8</TextWellPlateVertical>
  			<TextWellPlateVertical>9</TextWellPlateVertical>
  			<TextWellPlateVertical>10</TextWellPlateVertical>
  			<TextWellPlateVertical>11</TextWellPlateVertical>
  			<TextWellPlateVertical>12</TextWellPlateVertical>
  			<TextWellPlateVertical>13</TextWellPlateVertical>
  			<TextWellPlateVertical>14</TextWellPlateVertical>
  			<TextWellPlateVertical>15</TextWellPlateVertical>
  			<TextWellPlateVertical>16</TextWellPlateVertical>
  			<TextWellPlateVertical>17</TextWellPlateVertical>
  			<TextWellPlateVertical>18</TextWellPlateVertical>
  			<TextWellPlateVertical>19</TextWellPlateVertical>
  			<TextWellPlateVertical>20</TextWellPlateVertical>
  			<TextWellPlateVertical>21</TextWellPlateVertical>
  			<TextWellPlateVertical>22</TextWellPlateVertical>
  			<TextWellPlateVertical>23</TextWellPlateVertical>
  			<TextWellPlateVertical>24</TextWellPlateVertical>
  			<TextWellPlateVertical>25</TextWellPlateVertical>
  			<TextWellPlateVertical>26</TextWellPlateVertical>
  			<TextWellPlateVertical>27</TextWellPlateVertical>
  			<TextWellPlateVertical>28</TextWellPlateVertical>
  			<TextWellPlateVertical>29</TextWellPlateVertical>
  			<TextWellPlateVertical>30</TextWellPlateVertical>
  			<TextWellPlateVertical>31</TextWellPlateVertical>
  			<TextWellPlateVertical>32</TextWellPlateVertical>
  			<TextWellPlateVertical>33</TextWellPlateVertical>
  			<TextWellPlateVertical>34</TextWellPlateVertical>
  			<TextWellPlateVertical>35</TextWellPlateVertical>
  			<TextWellPlateVertical>36</TextWellPlateVertical>
  			<TextWellPlateVertical>37</TextWellPlateVertical>
  			<TextWellPlateVertical>38</TextWellPlateVertical>
  			<TextWellPlateVertical>39</TextWellPlateVertical>
  			<TextWellPlateVertical>40</TextWellPlateVertical>
  			<TextWellPlateVertical>41</TextWellPlateVertical>
  			<TextWellPlateVertical>42</TextWellPlateVertical>
  			<TextWellPlateVertical>43</TextWellPlateVertical>
  			<TextWellPlateVertical>44</TextWellPlateVertical>
  			<TextWellPlateVertical>45</TextWellPlateVertical>
  			<TextWellPlateVertical>46</TextWellPlateVertical>
  			<TextWellPlateVertical>47</TextWellPlateVertical>
  			<TextWellPlateVertical>48</TextWellPlateVertical>
  			<TextWellPlateVertical>49</TextWellPlateVertical>
  			<TextWellPlateVertical>50</TextWellPlateVertical>
  			<TextWellPlateVertical>51</TextWellPlateVertical>
  			<TextWellPlateVertical>52</TextWellPlateVertical>
  			<TextWellPlateVertical>53</TextWellPlateVertical>
  			<TextWellPlateVertical>54</TextWellPlateVertical>
  			<TextWellPlateVertical>55</TextWellPlateVertical>
  			<TextWellPlateVertical>56</TextWellPlateVertical>
  			<TextWellPlateVertical>57</TextWellPlateVertical>
  			<TextWellPlateVertical>58</TextWellPlateVertical>
  			<TextFillColorTextBox>A5A6A1</TextFillColorTextBox>
  			<TextColorTextBox>23272E</TextColorTextBox>
  			<EnableTextBox>false</EnableTextBox>
  			<TextFontSize>12</TextFontSize>
  			<DrawText>true</DrawText>
  			<FlipText>false</FlipText>
  			<AgendaLineDistance>30</AgendaLineDistance>
  			<AgendaTextDistance>20</AgendaTextDistance>
  			<AgendaBulletWidth>15</AgendaBulletWidth>
  			<AgendaTextWidth>120</AgendaTextWidth>
  			<AgendaXPosition>20</AgendaXPosition>
  			<AgendaYPosition>0</AgendaYPosition>
  			<AgendaTextColor>D4D3CC</AgendaTextColor>
  			<AgendaFontSize>10</AgendaFontSize>
  			<EnableAgenda>true</EnableAgenda>
  			<DescriptionTextColor>000000</DescriptionTextColor>
  			<DescriptionFontSize>10</DescriptionFontSize>
  			<EnableDescription>true</EnableDescription>
  			<Description>{ScanningTemplate}movement diff </Description>
  			<BlinkerColorOff>006400</BlinkerColorOff>
  			<BlinkerColorOn>00FF00</BlinkerColorOn>
  			<BlinkerIntervall>500</BlinkerIntervall>
  			<ColorDesign>LeicaDesign</ColorDesign>
  			<ScanFieldStageStartPositionX>40002</ScanFieldStageStartPositionX>
  			<ScanFieldStageStartPositionY>31025</ScanFieldStageStartPositionY>
  			<ScanFieldStageDistanceX>450</ScanFieldStageDistanceX>
  			<ScanFieldStageDistanceY>450</ScanFieldStageDistanceY>
  			<ScanWellStageDistanceX>1750</ScanWellStageDistanceX>
  			<ScanWellStageDistanceY>1750</ScanWellStageDistanceY>
  			<ScanFieldArrayOffsetZ>0</ScanFieldArrayOffsetZ>
  			<AutoFocusPattern>IsStandardAFScanFieldPattern</AutoFocusPattern>
  			<AutoFocusColor>FF7F50</AutoFocusColor>
  			<AutoFocusScanFieldInterval>2</AutoFocusScanFieldInterval>
  			<AutoFocusScanRange>80</AutoFocusScanRange>
  			<AutoFocusSliceCount>20</AutoFocusSliceCount>
  			<EnableAutoFocusDZOffset>false</EnableAutoFocusDZOffset>
  			<AutoFocusDzOffset>-0</AutoFocusDzOffset>
  			<MatrixJobPattern/>
  			<ZUseMode>1</ZUseMode>
  			<DriftRepeatInterval>1</DriftRepeatInterval>
  			<ShowDriftCompensationFields>true</ShowDriftCompensationFields>
  			<PetriDishVisualisation>false</PetriDishVisualisation>
  			<SelectedAutofocusJobName>AF Job</SelectedAutofocusJobName>
  			<SelectedTrackJobName>Job 2</SelectedTrackJobName>
  			<IsOverlapInPercentSelected>true</IsOverlapInPercentSelected>
  			<MosaicOverlapInPercent>10</MosaicOverlapInPercent>
  			<MosaicOverlapInMicronsX>0</MosaicOverlapInMicronsX>
  			<MosaicOverlapInMicronsY>0</MosaicOverlapInMicronsY>
  			<CanDoRealTime3D>false</CanDoRealTime3D>
  			<AutoRotate3D>false</AutoRotate3D>
  		</Properties>
  	</ScanningTemplate>
  	<ScanFieldArray>
  		<ScanFieldData AFJobId="0" AFScanRange="0" AFScore="0" AFSliceCount="0" Description="MatrixScreener" DriftScanRange="0" DriftSliceCount="0" Enabled="true" FieldX="1" FieldY="1" Indicator="IsStandardScanField" IsAutofocusScanField="false" IsDriftCompensationField="false" IsIndividualAutofocusScanField="false" IsMosaicCalibrationField="false" IsPumpScanField="false" IsTrackingField="false" JobAssigned="true" JobId="8" JobName="Job 2" LabelX="A" LabelY="1" PumpDelay="1000" PumpTime="1000" Selected="false" Shape="IsRectangle" SlideNo="0" State="IsActive" WellX="1" WellY="1">
- 			<FieldXCoordinate>0.040102</FieldXCoordinate>
? 			                        ^^

+ 			<FieldXCoordinate>0.0411019999999999996</FieldXCoordinate>
? 			                      ++  ^^^^^^^^^^^^^

- 			<FieldYCoordinate>0.030924999999999998</FieldYCoordinate>
? 			                                     ^

+ 			<FieldYCoordinate>0.0309249999999999976</FieldYCoordinate>
? 			                                     ^^

- 			<FieldZCoordinate>-2.3841880645312022E-10</FieldZCoordinate>
? 			                    -        - ----------

+ 			<FieldZCoordinate>-0.0000000002384188065</FieldZCoordinate>
? 			                   +++++++++++

  			<FieldScanSlices>0</FieldScanSlices>
  			<FieldScanRange>0</FieldScanRange>
  			<FieldRotation>0</FieldRotation>
  		</ScanFieldData>
  		<ScanFieldData AFJobId="0" AFScanRange="0" AFScore="0" AFSliceCount="0" Description="MatrixScreener" DriftScanRange="0" DriftSliceCount="0" Enabled="true" FieldX="1" FieldY="2" Indicator="IsStandardScanField" IsAutofocusScanField="false" IsDriftCompensationField="false" IsIndividualAutofocusScanField="false" IsMosaicCalibrationField="false" IsPumpScanField="false" IsTrackingField="false" JobAssigned="true" JobId="8" JobName="Job 2" LabelX="A" LabelY="1" PumpDelay="1000" PumpTime="1000" Selected="false" Shape="IsRectangle" SlideNo="0" State="IsActive" WellX="1" WellY="1">
- 			<FieldXCoordinate>0.040102</FieldXCoordinate>
? 			                        ^^

+ 			<FieldXCoordinate>0.0411019999999999996</FieldXCoordinate>
? 			                      ++  ^^^^^^^^^^^^^

- 			<FieldYCoordinate>0.031374999999999993</FieldYCoordinate>
+ 			<FieldYCoordinate>0.0313749999999999932</FieldYCoordinate>
? 			                                      +

- 			<FieldZCoordinate>-2.3841880645312022E-10</FieldZCoordinate>
? 			                    -        - ----------

+ 			<FieldZCoordinate>-0.0000000002384188065</FieldZCoordinate>
? 			                   +++++++++++

  			<FieldScanSlices>0</FieldScanSlices>
  			<FieldScanRange>0</FieldScanRange>
  			<FieldRotation>0</FieldRotation>
  		</ScanFieldData>
  		<ScanFieldData AFJobId="0" AFScanRange="0" AFScore="0" AFSliceCount="0" Description="MatrixScreener" DriftScanRange="0" DriftSliceCount="0" Enabled="true" FieldX="2" FieldY="1" Indicator="IsStandardScanField" IsAutofocusScanField="false" IsDriftCompensationField="false" IsIndividualAutofocusScanField="false" IsMosaicCalibrationField="false" IsPumpScanField="false" IsTrackingField="false" JobAssigned="true" JobId="8" JobName="Job 2" LabelX="A" LabelY="1" PumpDelay="1000" PumpTime="1000" Selected="false" Shape="IsRectangle" SlideNo="0" State="IsActive" WellX="1" WellY="1">
- 			<FieldXCoordinate>0.040552</FieldXCoordinate>
? 			                      ^  ^

+ 			<FieldXCoordinate>0.0415519999999999987</FieldXCoordinate>
? 			                      ^  ^^^^^^^^^^^^^^

- 			<FieldYCoordinate>0.030924999999999998</FieldYCoordinate>
? 			                                     ^

+ 			<FieldYCoordinate>0.0309249999999999976</FieldYCoordinate>
? 			                                     ^^

- 			<FieldZCoordinate>-2.3841880645312022E-10</FieldZCoordinate>
? 			                    -        - ----------

+ 			<FieldZCoordinate>-0.0000000002384188065</FieldZCoordinate>
? 			                   +++++++++++

  			<FieldScanSlices>0</FieldScanSlices>
  			<FieldScanRange>0</FieldScanRange>
  			<FieldRotation>0</FieldRotation>
  		</ScanFieldData>
  		<ScanFieldData AFJobId="0" AFScanRange="0" AFScore="0" AFSliceCount="0" Description="MatrixScreener" DriftScanRange="0" DriftSliceCount="0" Enabled="true" FieldX="2" FieldY="2" Indicator="IsStandardScanField" IsAutofocusScanField="false" IsDriftCompensationField="false" IsIndividualAutofocusScanField="false" IsMosaicCalibrationField="false" IsPumpScanField="false" IsTrackingField="false" JobAssigned="true" JobId="8" JobName="Job 2" LabelX="A" LabelY="1" PumpDelay="1000" PumpTime="1000" Selected="false" Shape="IsRectangle" SlideNo="0" State="IsActive" WellX="1" WellY="1">
- 			<FieldXCoordinate>0.040552</FieldXCoordinate>
? 			                      ^  ^

+ 			<FieldXCoordinate>0.0415519999999999987</FieldXCoordinate>
? 			                      ^  ^^^^^^^^^^^^^^

- 			<FieldYCoordinate>0.031374999999999993</FieldYCoordinate>
+ 			<FieldYCoordinate>0.0313749999999999932</FieldYCoordinate>
? 			                                      +

- 			<FieldZCoordinate>-2.3841880645312022E-10</FieldZCoordinate>
? 			                    -        - ----------

+ 			<FieldZCoordinate>-0.0000000002384188065</FieldZCoordinate>
? 			                   +++++++++++

  			<FieldScanSlices>0</FieldScanSlices>
  			<FieldScanRange>0</FieldScanRange>
  			<FieldRotation>0</FieldRotation>
  		</ScanFieldData>
  		<ScanFieldData AFJobId="0" AFScanRange="0" AFScore="0" AFSliceCount="0" Description="MatrixScreener" DriftScanRange="0" DriftSliceCount="0" Enabled="true" FieldX="1" FieldY="1" Indicator="IsStandardScanField" IsAutofocusScanField="false" IsDriftCompensationField="false" IsIndividualAutofocusScanField="false" IsMosaicCalibrationField="false" IsPumpScanField="false" IsTrackingField="false" JobAssigned="true" JobId="8" JobName="Job 2" LabelX="A" LabelY="2" PumpDelay="1000" PumpTime="1000" Selected="false" Shape="IsRectangle" SlideNo="0" State="IsActive" WellX="1" WellY="2">
  			<FieldXCoordinate>0.040001999999999996</FieldXCoordinate>
  			<FieldYCoordinate>0.032775</FieldYCoordinate>
  			<FieldZCoordinate>-2.3841880645312022E-10</FieldZCoordinate>
  			<FieldScanSlices>0</FieldScanSlices>
  			<FieldScanRange>0</FieldScanRange>
  			<FieldRotation>0</FieldRotation>
  		</ScanFieldData>
  		<ScanFieldData AFJobId="0" AFScanRange="0" AFScore="0" AFSliceCount="0" Description="MatrixScreener" DriftScanRange="0" DriftSliceCount="0" Enabled="true" FieldX="1" FieldY="2" Indicator="IsStandardScanField" IsAutofocusScanField="false" IsDriftCompensationField="false" IsIndividualAutofocusScanField="false" IsMosaicCalibrationField="false" IsPumpScanField="false" IsTrackingField="false" JobAssigned="true" JobId="8" JobName="Job 2" LabelX="A" LabelY="2" PumpDelay="1000" PumpTime="1000" Selected="false" Shape="IsRectangle" SlideNo="0" State="IsActive" WellX="1" WellY="2">
  			<FieldXCoordinate>0.040001999999999996</FieldXCoordinate>
  			<FieldYCoordinate>0.033225</FieldYCoordinate>
  			<FieldZCoordinate>-2.3841880645312022E-10</FieldZCoordinate>
  			<FieldScanSlices>0</FieldScanSlices>
  			<FieldScanRange>0</FieldScanRange>
  			<FieldRotation>0</FieldRotation>
  		</ScanFieldData>
  		<ScanFieldData AFJobId="0" AFScanRange="0" AFScore="0" AFSliceCount="0" Description="MatrixScreener" DriftScanRange="0" DriftSliceCount="0" Enabled="true" FieldX="2" FieldY="1" Indicator="IsStandardScanField" IsAutofocusScanField="false" IsDriftCompensationField="false" IsIndividualAutofocusScanField="false" IsMosaicCalibrationField="false" IsPumpScanField="false" IsTrackingField="false" JobAssigned="true" JobId="8" JobName="Job 2" LabelX="A" LabelY="2" PumpDelay="1000" PumpTime="1000" Selected="false" Shape="IsRectangle" SlideNo="0" State="IsActive" WellX="1" WellY="2">
  			<FieldXCoordinate>0.040451999999999995</FieldXCoordinate>
  			<FieldYCoordinate>0.032775</FieldYCoordinate>
  			<FieldZCoordinate>-2.3841880645312022E-10</FieldZCoordinate>
  			<FieldScanSlices>0</FieldScanSlices>
  			<FieldScanRange>0</FieldScanRange>
  			<FieldRotation>0</FieldRotation>
  		</ScanFieldData>
  		<ScanFieldData AFJobId="0" AFScanRange="0" AFScore="0" AFSliceCount="0" Description="MatrixScreener" DriftScanRange="0" DriftSliceCount="0" Enabled="true" FieldX="2" FieldY="2" Indicator="IsStandardScanField" IsAutofocusScanField="false" IsDriftCompensationField="false" IsIndividualAutofocusScanField="false" IsMosaicCalibrationField="false" IsPumpScanField="false" IsTrackingField="false" JobAssigned="true" JobId="8" JobName="Job 2" LabelX="A" LabelY="2" PumpDelay="1000" PumpTime="1000" Selected="false" Shape="IsRectangle" SlideNo="0" State="IsActive" WellX="1" WellY="2">
  			<FieldXCoordinate>0.040451999999999995</FieldXCoordinate>
  			<FieldYCoordinate>0.033225</FieldYCoordinate>
  			<FieldZCoordinate>-2.3841880645312022E-10</FieldZCoordinate>
  			<FieldScanSlices>0</FieldScanSlices>
  			<FieldScanRange>0</FieldScanRange>
  			<FieldRotation>0</FieldRotation>
  		</ScanFieldData>
  		<ScanFieldData AFJobId="0" AFScanRange="0" AFScore="0" AFSliceCount="0" Description="MatrixScreener" DriftScanRange="0" DriftSliceCount="0" Enabled="true" FieldX="1" FieldY="1" Indicator="IsStandardScanField" IsAutofocusScanField="false" IsDriftCompensationField="false" IsIndividualAutofocusScanField="false" IsMosaicCalibrationField="false" IsPumpScanField="false" IsTrackingField="false" JobAssigned="true" JobId="8" JobName="Job 2" LabelX="B" LabelY="1" PumpDelay="1000" PumpTime="1000" Selected="false" Shape="IsRectangle" SlideNo="0" State="IsActive" WellX="2" WellY="1">
  			<FieldXCoordinate>0.041752</FieldXCoordinate>
  			<FieldYCoordinate>0.031024999999999997</FieldYCoordinate>
  			<FieldZCoordinate>-2.3841880645312022E-10</FieldZCoordinate>
  			<FieldScanSlices>0</FieldScanSlices>
  			<FieldScanRange>0</FieldScanRange>
  			<FieldRotation>0</FieldRotation>
  		</ScanFieldData>
  		<ScanFieldData AFJobId="0" AFScanRange="0" AFScore="0" AFSliceCount="0" Description="MatrixScreener" DriftScanRange="0" DriftSliceCount="0" Enabled="true" FieldX="1" FieldY="2" Indicator="IsStandardScanField" IsAutofocusScanField="false" IsDriftCompensationField="false" IsIndividualAutofocusScanField="false" IsMosaicCalibrationField="false" IsPumpScanField="false" IsTrackingField="false" JobAssigned="true" JobId="8" JobName="Job 2" LabelX="B" LabelY="1" PumpDelay="1000" PumpTime="1000" Selected="false" Shape="IsRectangle" SlideNo="0" State="IsActive" WellX="2" WellY="1">
  			<FieldXCoordinate>0.041752</FieldXCoordinate>
  			<FieldYCoordinate>0.031474999999999996</FieldYCoordinate>
  			<FieldZCoordinate>-2.3841880645312022E-10</FieldZCoordinate>
  			<FieldScanSlices>0</FieldScanSlices>
  			<FieldScanRange>0</FieldScanRange>
  			<FieldRotation>0</FieldRotation>
  		</ScanFieldData>
  		<ScanFieldData AFJobId="0" AFScanRange="0" AFScore="0" AFSliceCount="0" Description="MatrixScreener" DriftScanRange="0" DriftSliceCount="0" Enabled="true" FieldX="2" FieldY="1" Indicator="IsStandardScanField" IsAutofocusScanField="false" IsDriftCompensationField="false" IsIndividualAutofocusScanField="false" IsMosaicCalibrationField="false" IsPumpScanField="false" IsTrackingField="false" JobAssigned="true" JobId="8" JobName="Job 2" LabelX="B" LabelY="1" PumpDelay="1000" PumpTime="1000" Selected="false" Shape="IsRectangle" SlideNo="0" State="IsActive" WellX="2" WellY="1">
  			<FieldXCoordinate>0.042201999999999996</FieldXCoordinate>
  			<FieldYCoordinate>0.031024999999999997</FieldYCoordinate>
  			<FieldZCoordinate>-2.3841880645312022E-10</FieldZCoordinate>
  			<FieldScanSlices>0</FieldScanSlices>
  			<FieldScanRange>0</FieldScanRange>
  			<FieldRotation>0</FieldRotation>
  		</ScanFieldData>
  		<ScanFieldData AFJobId="0" AFScanRange="0" AFScore="0" AFSliceCount="0" Description="MatrixScreener" DriftScanRange="0" DriftSliceCount="0" Enabled="true" FieldX="2" FieldY="2" Indicator="IsStandardScanField" IsAutofocusScanField="false" IsDriftCompensationField="false" IsIndividualAutofocusScanField="false" IsMosaicCalibrationField="false" IsPumpScanField="false" IsTrackingField="false" JobAssigned="true" JobId="8" JobName="Job 2" LabelX="B" LabelY="1" PumpDelay="1000" PumpTime="1000" Selected="false" Shape="IsRectangle" SlideNo="0" State="IsActive" WellX="2" WellY="1">
  			<FieldXCoordinate>0.042201999999999996</FieldXCoordinate>
  			<FieldYCoordinate>0.031474999999999996</FieldYCoordinate>
  			<FieldZCoordinate>-2.3841880645312022E-10</FieldZCoordinate>
  			<FieldScanSlices>0</FieldScanSlices>
  			<FieldScanRange>0</FieldScanRange>
  			<FieldRotation>0</FieldRotation>
  		</ScanFieldData>
  		<ScanFieldData AFJobId="0" AFScanRange="0" AFScore="0" AFSliceCount="0" Description="MatrixScreener" DriftScanRange="0" DriftSliceCount="0" Enabled="true" FieldX="1" FieldY="1" Indicator="IsStandardScanField" IsAutofocusScanField="false" IsDriftCompensationField="false" IsIndividualAutofocusScanField="false" IsMosaicCalibrationField="false" IsPumpScanField="false" IsTrackingField="false" JobAssigned="true" JobId="8" JobName="Job 2" LabelX="B" LabelY="2" PumpDelay="1000" PumpTime="1000" Selected="false" Shape="IsRectangle" SlideNo="0" State="IsActive" WellX="2" WellY="2">
  			<FieldXCoordinate>0.041752</FieldXCoordinate>
  			<FieldYCoordinate>0.032775</FieldYCoordinate>
  			<FieldZCoordinate>-2.3841880645312022E-10</FieldZCoordinate>
  			<FieldScanSlices>0</FieldScanSlices>
  			<FieldScanRange>0</FieldScanRange>
  			<FieldRotation>0</FieldRotation>
  		</ScanFieldData>
  		<ScanFieldData AFJobId="0" AFScanRange="0" AFScore="0" AFSliceCount="0" Description="MatrixScreener" DriftScanRange="0" DriftSliceCount="0" Enabled="true" FieldX="1" FieldY="2" Indicator="IsStandardScanField" IsAutofocusScanField="false" IsDriftCompensationField="false" IsIndividualAutofocusScanField="false" IsMosaicCalibrationField="false" IsPumpScanField="false" IsTrackingField="false" JobAssigned="true" JobId="8" JobName="Job 2" LabelX="B" LabelY="2" PumpDelay="1000" PumpTime="1000" Selected="false" Shape="IsRectangle" SlideNo="0" State="IsActive" WellX="2" WellY="2">
  			<FieldXCoordinate>0.041752</FieldXCoordinate>
  			<FieldYCoordinate>0.033225</FieldYCoordinate>
  			<FieldZCoordinate>-2.3841880645312022E-10</FieldZCoordinate>
  			<FieldScanSlices>0</FieldScanSlices>
  			<FieldScanRange>0</FieldScanRange>
  			<FieldRotation>0</FieldRotation>
  		</ScanFieldData>
  		<ScanFieldData AFJobId="0" AFScanRange="0" AFScore="0" AFSliceCount="0" Description="MatrixScreener" DriftScanRange="0" DriftSliceCount="0" Enabled="true" FieldX="2" FieldY="1" Indicator="IsStandardScanField" IsAutofocusScanField="false" IsDriftCompensationField="false" IsIndividualAutofocusScanField="false" IsMosaicCalibrationField="false" IsPumpScanField="false" IsTrackingField="false" JobAssigned="true" JobId="8" JobName="Job 2" LabelX="B" LabelY="2" PumpDelay="1000" PumpTime="1000" Selected="false" Shape="IsRectangle" SlideNo="0" State="IsActive" WellX="2" WellY="2">
  			<FieldXCoordinate>0.042201999999999996</FieldXCoordinate>
  			<FieldYCoordinate>0.032775</FieldYCoordinate>
  			<FieldZCoordinate>-2.3841880645312022E-10</FieldZCoordinate>
  			<FieldScanSlices>0</FieldScanSlices>
  			<FieldScanRange>0</FieldScanRange>
  			<FieldRotation>0</FieldRotation>
  		</ScanFieldData>
  		<ScanFieldData AFJobId="0" AFScanRange="0" AFScore="0" AFSliceCount="0" Description="MatrixScreener" DriftScanRange="0" DriftSliceCount="0" Enabled="true" FieldX="2" FieldY="2" Indicator="IsStandardScanField" IsAutofocusScanField="false" IsDriftCompensationField="false" IsIndividualAutofocusScanField="false" IsMosaicCalibrationField="false" IsPumpScanField="false" IsTrackingField="false" JobAssigned="true" JobId="8" JobName="Job 2" LabelX="B" LabelY="2" PumpDelay="1000" PumpTime="1000" Selected="false" Shape="IsRectangle" SlideNo="0" State="IsActive" WellX="2" WellY="2">
  			<FieldXCoordinate>0.042201999999999996</FieldXCoordinate>
  			<FieldYCoordinate>0.033225</FieldYCoordinate>
  			<FieldZCoordinate>-2.3841880645312022E-10</FieldZCoordinate>
  			<FieldScanSlices>0</FieldScanSlices>
  			<FieldScanRange>0</FieldScanRange>
  			<FieldRotation>0</FieldRotation>
  		</ScanFieldData>
  	</ScanFieldArray>
  	<ScanWellArray>
- 		<ScanWellData FieldXStartCoordinate="0.040102" FieldYStartCoordinate="0.030924999999999998" FieldZCoordinate="-2.3841880645312022E-10" Indicator="IsStandardScanWell" MosaicFlipImage="false" MosaicImageEndX="0.04000241115938" MosaicImageEndY="0.031025667708599998" MosaicImageHeight="0" MosaicImageStartX="0.04000241115938" MosaicImageStartY="0.031025667708599998" MosaicImageWidth="0" MosaicScanImageRotation="0" MosaicSingleImageHeight="0.00058125" MosaicSingleImageWidth="0.00058125" MosaicTileImageOverlapX="0" MosaicTileImageOverlapY="0" ScanFieldDiameter="0" SlideNo="1" WellX="1" WellXOffset="0" WellY="1" WellYOffset="0" XCountOfFields="2" YCountOfFields="2"/>
? 		                                         ^^^^                                            ^                     ^^        ^^^^^^^^^^^^

+ 		<ScanWellData FieldXStartCoordinate="0.0411019999999999996" FieldYStartCoordinate="0.0309249999999999976" FieldZCoordinate="-0.0000000002384188065" Indicator="IsStandardScanWell" MosaicFlipImage="false" MosaicImageEndX="0.04000241115938" MosaicImageEndY="0.031025667708599998" MosaicImageHeight="0" MosaicImageStartX="0.04000241115938" MosaicImageStartY="0.031025667708599998" MosaicImageWidth="0" MosaicScanImageRotation="0" MosaicSingleImageHeight="0.00058125" MosaicSingleImageWidth="0.00058125" MosaicTileImageOverlapX="0" MosaicTileImageOverlapY="0" ScanFieldDiameter="0" SlideNo="1" WellX="1" WellXOffset="0" WellY="1" WellYOffset="0" XCountOfFields="2" YCountOfFields="2"/>
? 		                                         ^^^^^^^^^^^^^^^^^                                            ^^                     ^^^^^^^^^^^^        ^

  		<ScanWellData FieldXStartCoordinate="0.040001999999999996" FieldYStartCoordinate="0.032775" FieldZCoordinate="-2.3841880645312022E-10" Indicator="IsStandardScanWell" MosaicFlipImage="false" MosaicImageEndX="0.04000241115938" MosaicImageEndY="0.031025667708599998" MosaicImageHeight="0" MosaicImageStartX="0.04000241115938" MosaicImageStartY="0.031025667708599998" MosaicImageWidth="0" MosaicScanImageRotation="0" MosaicSingleImageHeight="0.00058125" MosaicSingleImageWidth="0.00058125" MosaicTileImageOverlapX="0" MosaicTileImageOverlapY="0" ScanFieldDiameter="0" SlideNo="1" WellX="1" WellXOffset="0" WellY="2" WellYOffset="0" XCountOfFields="2" YCountOfFields="2"/>
  		<ScanWellData FieldXStartCoordinate="0.041752" FieldYStartCoordinate="0.031024999999999997" FieldZCoordinate="-2.3841880645312022E-10" Indicator="IsStandardScanWell" MosaicFlipImage="false" MosaicImageEndX="0.04000241115938" MosaicImageEndY="0.031025667708599998" MosaicImageHeight="0" MosaicImageStartX="0.04000241115938" MosaicImageStartY="0.031025667708599998" MosaicImageWidth="0" MosaicScanImageRotation="0" MosaicSingleImageHeight="0.00058125" MosaicSingleImageWidth="0.00058125" MosaicTileImageOverlapX="0" MosaicTileImageOverlapY="0" ScanFieldDiameter="0" SlideNo="1" WellX="2" WellXOffset="0" WellY="1" WellYOffset="0" XCountOfFields="2" YCountOfFields="2"/>
  		<ScanWellData FieldXStartCoordinate="0.041752" FieldYStartCoordinate="0.032775" FieldZCoordinate="-2.3841880645312022E-10" Indicator="IsStandardScanWell" MosaicFlipImage="false" MosaicImageEndX="0.04000241115938" MosaicImageEndY="0.031025667708599998" MosaicImageHeight="0" MosaicImageStartX="0.04000241115938" MosaicImageStartY="0.031025667708599998" MosaicImageWidth="0" MosaicScanImageRotation="0" MosaicSingleImageHeight="0.00058125" MosaicSingleImageWidth="0.00058125" MosaicTileImageOverlapX="0" MosaicTileImageOverlapY="0" ScanFieldDiameter="0" SlideNo="1" WellX="2" WellXOffset="0" WellY="2" WellYOffset="0" XCountOfFields="2" YCountOfFields="2"/>
  	</ScanWellArray>
  </MatrixScreenerTemplate>

# %% [markdown]
# # LRP

# %%
filename = filename[:-3] + 'lrp'

xml_orig = pretty_xml(path.join(root, comp1, filename))
xml_diff = pretty_xml(path.join(root, comp2, filename))

# %%
diff = compare(xml_orig, xml_diff)
diff_str = "\n".join(diff)

# %%
load(diff_str)

# %% [markdown]
# # LRP diff
# Templates:
# - dx dy a1
# - dx dy b2

# %%
# %%writefile diff.lrp
#   <?xml version="1.0" ?>
#   <!--Leica Application Suite Advanced Fluorescence Software (LAS-AF)-->
#   <!--Leica Microsystems CMS GmbH-->
#   <!--http://www.confocal-microscopy.com-->
#   <!--LAS-AF 3.3.0.10134-->
# - <Configuration ID="562311879" SystemType="-1" Type="7">
# ?                    ^^  ^^^ -
#
# + <Configuration ID="944292337" SystemType="-1" Type="7">
# ?                    ^^^^^  ^
#
#   	<LDM_Block_Sequence BlockName="collecting pattern">
#   		<LDM_Block_Sequence_Element_List>
#   			<LDM_Block_Sequence_Element AFLinkBlockID="0" AF_LDM_Mode="0" AF_Offset="0" BlockID="7" BlockType="0" ElementID="1" IsLoopActive="0" LoopCount="-1" LoopToNextElement="0" PauseTime="0" RemainingLoopCount="-1" WFInTriggerMode="-1" WFOutTriggerMode="-1" WaitTimeBeforeDelayTriggerOut="0" m_eInTrigger="-1" m_eInTriggerDescription="" m_eInTriggerRecordInEventlist="0" m_eInTriggerShowInGraph="1" m_eOutTrigger="-1" m_eOutTriggerDescription="" m_eOutTriggerOnDelay="-1" m_eOutTriggerOnDelayDescription="" m_eOutTriggerOnDelayRecordInEventlist="1" m_eOutTriggerOnDelayShowInGraph="1" m_eOutTriggerOnEnd="-1" m_eOutTriggerOnEndDescription="" m_eOutTriggerOnEndRecordInEventlist="1" m_eOutTriggerOnEndShowInGraph="1" m_eOutTriggerOnStart="-1" m_eOutTriggerOnStartDescription="" m_eOutTriggerOnStartRecordInEventlist="1" m_eOutTriggerOnStartShowInGraph="1" m_eOutTriggerRecordInEventlist="1" m_eOutTriggerShowInGraph="1"/>
#   			<LDM_Block_Sequence_Element AFLinkBlockID="0" AF_LDM_Mode="0" AF_Offset="0" BlockID="8" BlockType="0" ElementID="2" IsLoopActive="0" LoopCount="-1" LoopToNextElement="0" PauseTime="0" RemainingLoopCount="-1" WFInTriggerMode="-1" WFOutTriggerMode="-1" WaitTimeBeforeDelayTriggerOut="0" m_eInTrigger="-1" m_eInTriggerDescription="" m_eInTriggerRecordInEventlist="0" m_eInTriggerShowInGraph="1" m_eOutTrigger="-1" m_eOutTriggerDescription="" m_eOutTriggerOnDelay="-1" m_eOutTriggerOnDelayDescription="" m_eOutTriggerOnDelayRecordInEventlist="1" m_eOutTriggerOnDelayShowInGraph="1" m_eOutTriggerOnEnd="-1" m_eOutTriggerOnEndDescription="" m_eOutTriggerOnEndRecordInEventlist="1" m_eOutTriggerOnEndShowInGraph="1" m_eOutTriggerOnStart="-1" m_eOutTriggerOnStartDescription="" m_eOutTriggerOnStartRecordInEventlist="1" m_eOutTriggerOnStartShowInGraph="1" m_eOutTriggerRecordInEventlist="1" m_eOutTriggerShowInGraph="1"/>
#   		</LDM_Block_Sequence_Element_List>
#   		<LDM_Block_Sequence_Block_List>
#   			<LDM_Block_Sequence_Block BlockID="7" BlockIsUsingCameraImageSource="0" BlockType="0">
#   				<LDM_Block BlockName="AF Job">
# - 					<ATLConfocalSettingDefinition ActiveCS_SubModeForRLD="0" ActiveCS_SubModeForRLDName="Empty" ActiveCS_SubModeForTLD="0" ActiveCS_SubModeForTLDName="Scan-BF" AdaptiveFocusControlActive="1" AdaptiveFocusControlAutonomousModeActive="0" AdaptiveFocusControlAutonomousOffset="-1" AotfValidBegin="0" AotfValidEnd="0" AreBleachPointsEnabled="0" AutoFocusMode="2" AutoFocusModeName="FirstChannelOnly" AutofocusChannel="1" AutofocusRedoEveryNTimePoints="0" BaseZoom="0.75" BitSize="8" CanDoCSMode="1" CanDoOpticalZoom="0" CanDoSTED="0" CompleteTime="1.293" CycleCount="1" CycleTime="0" DetectorValidBegin="0" DetectorValidEnd="0" EmissionWavelengthForPinholeAiryCalculation="580" FrameAccumulation="1" FrameAverage="1" FrameTime="1.293" Immersion="DRY" InDimension="512" InTrigger="-1" Is3DLimitedRoiScanEnable="0" IsAFCOnStart="0" IsAutofocusOnStart="1" IsConstantIntegrationTimeActive="1" IsFCSFilterAutomationActive="0" IsFastZStack="0" IsInverseMicroscopeModel="1" IsMPFormulaForStepSizerUsageActive="0" IsRoiScanEnable="0" IsSMDChaserUVAOTFAutomationActive="0" IsSTEDActive="0" IsSuperZ="0" IsTimeMinimizeEnabled="0" IsUserSettingNameSet="0" IsZStackAroundCurrent="0" LambdaExcitationMode="0" LambdaExcitationModeBegin="0" LambdaExcitationModeEnd="0" LastNonMP_MFP_FW_Name="Substrate " LastNonMP_Pol_FW_Name="Empty" LastTCalcMode="3" Limited3DRoiFirstSection="1" Limited3DRoiLastSection="1" LineAverage="1" LineTime="0.0025" Line_Accumulation="1" Lines="512" Magnification="20" MaxLines="1" MicroscopeModel="DMI6000B-CS" MotCorrPosDevBegin="-1" MotCorrPosDevEnd="-1" MotCorrPosition="6.62037037037037" MotCorrSlotIndexBegin="-1" MotCorrSlotIndexEnd="-1" MotCorrValidBegin="0" MotCorrValidEnd="0" NumericalAperture="0.75" ObjectiveName="HCX PL APO CS    20x/0.75 DRY " ObjectiveNumber="11506517" ObjectivePos="1" OpticalZoom="1" OutDimension="512" OutTrigger="-1" Pages="1" PanFirstDim="8.67361737988404E-19" PanSecondDim="8.67361737988404E-19" Pinhole="5.66408184255765E-05" PinholeAiry="1.00057974889727" PixelDwellTime="0.0000012" RefractionIndex="1" RotatorAngle="0" STEDDelayTimeOffset="0" STEDDelayTimeOffset2="0" ScanDirectionX="1" ScanDirectionXName="Unidirectional" ScanMode="xyz" ScanSpeed="400" Sections="1" StackCalculationMode="2" StackCalculationModeName="System optimized step size" StagePosX="0.04010200095214" StagePosY="0.03092499881483" StageRangeX="0.11279375084332" StageRangeY="0.07937695154648" SystemSerialNumber="8100000303" UseMaxIterationsForT="0" UseScanFormatRestriction="0" UseSystemOptimizedVoxelCalculation="1" UserSettingName="S6" ValidBeginStack="0" ValidEndStack="0" VersionNumber="6" ZIntensityCompensationMode="0" ZIntensityCompensationModeName="None" ZPosition="-2.3841880645312E-10" ZStackDirectionMode="1" ZStackDirectionModeName="Unidirectional" ZUseMode="1" ZUseModeName="z-galvo" Zoom="1">
# ? 					                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ^^^^^^^^  ^                  --     ^^ -
#
# + 					<ATLConfocalSettingDefinition ActiveCS_SubModeForRLD="0" ActiveCS_SubModeForRLDName="Empty" ActiveCS_SubModeForTLD="0" ActiveCS_SubModeForTLDName="Scan-BF" AdaptiveFocusControlActive="1" AdaptiveFocusControlAutonomousModeActive="0" AdaptiveFocusControlAutonomousOffset="-1" AotfValidBegin="0" AotfValidEnd="0" AreBleachPointsEnabled="0" AutoFocusMode="2" AutoFocusModeName="FirstChannelOnly" AutofocusChannel="1" AutofocusRedoEveryNTimePoints="0" BaseZoom="0.75" BitSize="8" CanDoCSMode="1" CanDoOpticalZoom="0" CanDoSTED="0" CompleteTime="1.293" CycleCount="1" CycleTime="0" DetectorValidBegin="0" DetectorValidEnd="0" EmissionWavelengthForPinholeAiryCalculation="580" FrameAccumulation="1" FrameAverage="1" FrameTime="1.293" Immersion="DRY" InDimension="512" InTrigger="-1" Is3DLimitedRoiScanEnable="0" IsAFCOnStart="0" IsAutofocusOnStart="1" IsConstantIntegrationTimeActive="1" IsFCSFilterAutomationActive="0" IsFastZStack="0" IsInverseMicroscopeModel="1" IsMPFormulaForStepSizerUsageActive="0" IsRoiScanEnable="0" IsSMDChaserUVAOTFAutomationActive="0" IsSTEDActive="0" IsSuperZ="0" IsTimeMinimizeEnabled="0" IsUserSettingNameSet="0" IsZStackAroundCurrent="0" LambdaExcitationMode="0" LambdaExcitationModeBegin="0" LambdaExcitationModeEnd="0" LastNonMP_MFP_FW_Name="Substrate " LastNonMP_Pol_FW_Name="Empty" LastTCalcMode="3" Limited3DRoiFirstSection="1" Limited3DRoiLastSection="1" LineAverage="1" LineTime="0.0025" Line_Accumulation="1" Lines="512" Magnification="20" MaxLines="1" MicroscopeModel="DMI6000B-CS" MotCorrPosDevBegin="-1" MotCorrPosDevEnd="-1" MotCorrPosition="6.62037037037037" MotCorrSlotIndexBegin="-1" MotCorrSlotIndexEnd="-1" MotCorrValidBegin="0" MotCorrValidEnd="0" NumericalAperture="0.75" ObjectiveName="HCX PL APO CS    20x/0.75 DRY " ObjectiveNumber="11506517" ObjectivePos="1" OpticalZoom="1" OutDimension="512" OutTrigger="-1" Pages="1" PanFirstDim="8.67361737988404E-19" PanSecondDim="8.67361737988404E-19" Pinhole="5.66408184255765E-05" PinholeAiry="1.00057974889727" PixelDwellTime="0.0000012" RefractionIndex="1" RotatorAngle="0" STEDDelayTimeOffset="0" STEDDelayTimeOffset2="0" ScanDirectionX="1" ScanDirectionXName="Unidirectional" ScanMode="xyz" ScanSpeed="400" Sections="1" StackCalculationMode="2" StackCalculationModeName="System optimized step size" StagePosX="0.04165200015854" StagePosY="0.03287499781643" StageRangeX="0.11279375084332" StageRangeY="0.07937695154648" SystemSerialNumber="8100000303" UseMaxIterationsForT="0" UseScanFormatRestriction="0" UseSystemOptimizedVoxelCalculation="1" UserSettingName="S6" ValidBeginStack="0" ValidEndStack="0" VersionNumber="6" ZIntensityCompensationMode="0" ZIntensityCompensationModeName="None" ZPosition="-2.3841880645312E-10" ZStackDirectionMode="1" ZStackDirectionModeName="Unidirectional" ZUseMode="1" ZUseModeName="z-galvo" Zoom="1">
# ? 					                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ^^  ^^^^^^^                   ++   + ^^
#
#   						<EasySRMappingArray/>
#   						<EasySRSlider GentleRelative="25" SRRelative="75" ThreeDRelative="0"/>
#   						<Quantity Unit="" Value="0"/>
#   						<AdditionalZPositionList>
#   							<AdditionalZPosition SuperZMode="1" SuperZModeName="RestrictedRange" Valid="1" ZMode="1" ZPosition="-2.3841880645312E-10" ZUseModeName="z-galvo"/>
#   							<AdditionalZPosition SuperZMode="1" SuperZModeName="RestrictedRange" Valid="1" ZMode="2" ZPosition="0" ZUseModeName="z-wide"/>
#   						</AdditionalZPositionList>
#   						<Autofocus-config AFAnalyseType="1" AFAnalyseTypeName="EveryChannel" AFCOffset="-2" AFSubsystem="0" AFSubsystemName="BaseAF" FocusRange="0.00008" Precision="2" UseFixSliceNumber="0" WorkflowTimelapse="1" WorkflowTimelapseIterator="1" WorkflowTimelapseName="FirstTime" WorkflowXY="1" WorkflowXYIterator="1" WorkflowXYName="FirstPos" ZUseMode="1" ZUseModeName="z-galvo"/>
#   						<ShutterList>
#   							<Shutter IsActive="0" LightSourceName="ChaserUV" LightSourceQualifier="60" ShutterName="ChaserUV" ShutterQualifier="6"/>
#   							<Shutter IsActive="0" LightSourceName="SuperCont" LightSourceQualifier="70" ShutterName="WLL" ShutterQualifier="8"/>
#   							<Shutter IsActive="0" LightSourceName="Vis" LightSourceQualifier="10" ShutterName="Visible" ShutterQualifier="3"/>
#   							<Shutter IsActive="0" LightSourceName="MP" LightSourceQualifier="40" ShutterName="MP" ShutterQualifier="4"/>
#   						</ShutterList>
#   						<BleachPoints>
#   							<LMSDataContainerHeader Version="2">
#   								<Element Name="BleachPointROISet" UniqueID="0cffdb84-9b07-11e4-9f85-bcf685d7650c">
#   									<Data>
#   										<ROISet PossibleChildROITypes="-1" PossibleROIActions="65535" PossibleROITransforms="65535" ROISetType="1"/>
#   									</Data>
#   									<Memory MemoryBlockID="MemBlock_27" Size="0"/>
#   									<Children/>
#   								</Element>
#   							</LMSDataContainerHeader>
#   						</BleachPoints>
#   						<ATLConfocalBleachPointsSettings/>
#   						<FilterWheel BeamSplitterAutoSelection="0" FluorifierAutoSelection="1" StedBeamSelectionPinholeCoupling="0">
#   							<Wheel FilterIndex="0" FilterName="Min" FilterSpectrumPos="3000" FilterWheelName="Attenuation MP" IndexChanged="0" IsSpectrumTurnMode="0" LightSourceQualifier="40" Qualifier="214" SpectrumChanged="0">
#   								<WheelName FilterName="Min"/>
#   								<WheelName FilterName="Max"/>
#   							</Wheel>
#   							<Wheel FilterIndex="2" FilterName="Mirror " FilterSpectrumPos="0" FilterWheelName="External Detection FW" IndexChanged="0" IsSpectrumTurnMode="0" Qualifier="140" SpectrumChanged="0">
#   								<WheelName FilterName="--- "/>
#   								<WheelName FilterName="Substrate "/>
#   								<WheelName FilterName="Mirror "/>
#   							</Wheel>
#   							<Wheel FilterIndex="0" FilterName="--- " FilterSpectrumPos="0" FilterWheelName="FCS-FW" IndexChanged="0" IsSpectrumTurnMode="0" Qualifier="26" SpectrumChanged="0">
#   								<WheelName FilterName="--- "/>
#   								<WheelName FilterName="CleaningFilter 458"/>
#   								<WheelName FilterName="CleaningFilter 488"/>
#   								<WheelName FilterName="CleaningFilter 514"/>
#   								<WheelName FilterName="CleaningFilter 458/514"/>
#   								<WheelName FilterName="--- "/>
#   								<WheelName FilterName="--- "/>
#   								<WheelName FilterName="--- "/>
#   							</Wheel>
#   							<Wheel FilterIndex="0" FilterName="Galvo X Normal " FilterSpectrumPos="0" FilterWheelName="Galvo Slider" IndexChanged="0" IsSpectrumTurnMode="0" Qualifier="160" SpectrumChanged="0">
#   								<WheelName FilterName="Galvo X Normal "/>
#   								<WheelName FilterName="Galvo X Res "/>
#   							</Wheel>
#   							<Wheel FilterIndex="4" FilterName="Substrate " FilterSpectrumPos="0" FilterWheelName="Multi Function Port" IndexChanged="0" IsSpectrumTurnMode="0" Qualifier="180" SpectrumChanged="0">
#   								<WheelName FilterName="--- "/>
#   								<WheelName FilterName="SP 815"/>
#   								<WheelName FilterName="SP 665"/>
#   								<WheelName FilterName="Mirror "/>
#   								<WheelName FilterName="Substrate "/>
#   							</Wheel>
#   							<Wheel FilterIndex="0" FilterName="Empty" FilterSpectrumPos="0" FilterWheelName="Notch FW 2" IndexChanged="0" IsSpectrumTurnMode="0" Qualifier="131" SpectrumChanged="0">
#   								<WheelName FilterName="Empty"/>
#   								<WheelName FilterName="--- "/>
#   								<WheelName FilterName="--- "/>
#   								<WheelName FilterName="--- "/>
#   								<WheelName FilterName="--- "/>
#   								<WheelName FilterName="--- "/>
#   								<WheelName FilterName="--- "/>
#   								<WheelName FilterName="MP1 SP 680"/>
#   								<WheelName FilterName="--- "/>
#   								<WheelName FilterName="OPO SP 800"/>
#   								<WheelName FilterName="SMD1 NF 405/470"/>
#   								<WheelName FilterName="SMD2 NF 405/640"/>
#   								<WheelName FilterName="SMD3 NF 470/640"/>
#   								<WheelName FilterName="--- "/>
#   							</Wheel>
#   							<Wheel FilterIndex="0" FilterName="Empty" FilterSpectrumPos="79246" FilterWheelName="Polarization FW" IndexChanged="0" IsSpectrumTurnMode="0" Qualifier="130" SpectrumChanged="0">
#   								<WheelName FilterName="Empty"/>
#   								<WheelName FilterName="NF 488"/>
#   								<WheelName FilterName="NF 514"/>
#   								<WheelName FilterName="NF 458/514"/>
#   								<WheelName FilterName="NF 488/561/633"/>
#   								<WheelName FilterName="--- "/>
#   							</Wheel>
#   							<Wheel FilterIndex="0" FilterName="Galvo X Pan Center " FilterSpectrumPos="0" FilterWheelName="Galvo Resonant Pan" IndexChanged="0" IsSpectrumTurnMode="0" Qualifier="200" SpectrumChanged="0">
#   								<WheelName FilterName="Galvo X Pan Center "/>
#   								<WheelName FilterName="Galvo X Pan Mirror "/>
#   								<WheelName FilterName="Galvo X Pan Polfilter "/>
#   								<WheelName FilterName="Galvo X Pan RefDiode "/>
#   							</Wheel>
#   							<Wheel FilterIndex="0" FilterName="Target Park " FilterSpectrumPos="0" FilterWheelName="Target Slider" IndexChanged="0" IsSpectrumTurnMode="0" Qualifier="170" SpectrumChanged="0">
#   								<WheelName FilterName="Target Park "/>
#   								<WheelName FilterName="Target Inserted "/>
#   								<WheelName FilterName="Target Mirror "/>
#   							</Wheel>
#   							<Wheel FilterIndex="0" FilterName="CS2 UV Optics 1 " FilterSpectrumPos="0" FilterWheelName="X2 Lens Changer" IndexChanged="0" IsSpectrumTurnMode="0" Qualifier="31" SpectrumChanged="0">
#   								<WheelName FilterName="CS2 UV Optics 1 "/>
#   								<WheelName FilterName="CS2 UV Optics 2 "/>
#   							</Wheel>
#   						</FilterWheel>
#   						<Spectro>
#   							<MultiBand Channel="1" ChannelName="Channel 1" DyeName="" LeftWorld="406.25" RightWorld="458.75"/>
#   							<MultiBand Channel="2" ChannelName="Channel 2" DyeName="" LeftWorld="511.25" RightWorld="563.75"/>
#   							<MultiBand Channel="3" ChannelName="Channel 3" DyeName="" LeftWorld="616.25" RightWorld="668.75"/>
#   							<MultiBand Channel="4" ChannelName="Channel 4" DyeName="" LeftWorld="721.25" RightWorld="773.75"/>
#   						</Spectro>
#   						<AotfList>
#   							<Aotf AotfQualifier="80" AotfQualifierName="ChaserUV" CanDoPulseFreq="1" CanDoTwoLaserPIE="0" IsChanged="0" LightSourceQualifier="60" LightSourceQualifierName="ChaserUV" OpenVirtual="0" PulsFreq="40000000" TwoLaserPIEActive="0" TwoLaserPIEPossibleLastState="0">
#   								<LaserLineSetting AOBSIntensityDev="-1" AOBSIntensityLowDev="-1" EnableDoubleMode="0" IntensityDev="0" IntensityLowDev="0" IsLineChecked="1" IsLineDeactivated="0" IsVisible="1" LaserLine="405" LineIndex="0" OutCheckedIntensity="0" Qualifier="80" SequenceIndex="0" SuppressionMode="-1"/>
#   							</Aotf>
#   							<Aotf AotfQualifier="90" AotfQualifierName="WLL" CanDoPulseFreq="0" CanDoTwoLaserPIE="0" ExcitationControlMode="0" ExcitationControlModeBegin="0" ExcitationControlModeEnd="0" IsChanged="0" LightSourceQualifier="70" LightSourceQualifierName="SuperCont" OpenVirtual="0" PulsFreq="0" TwoLaserPIEActive="0" TwoLaserPIEPossibleLastState="0">
#   								<LaserLineSetting AOBSIntensityDev="-1" AOBSIntensityLowDev="-1" EnableDoubleMode="0" IntensityDev="0" IntensityLowDev="0" IsLineChecked="0" IsLineDeactivated="0" IsVisible="1" LaserLine="470" LineIndex="0" OutCheckedIntensity="0" Qualifier="90" SequenceIndex="0" SuppressionMode="-1"/>
#   								<LaserLineSetting AOBSIntensityDev="-1" AOBSIntensityLowDev="-1" EnableDoubleMode="0" IntensityDev="0" IntensityLowDev="0" IsLineChecked="0" IsLineDeactivated="0" IsVisible="0" LaserLine="471" LineIndex="1" OutCheckedIntensity="0" Qualifier="90" SequenceIndex="0" SuppressionMode="-1"/>
#   								<LaserLineSetting AOBSIntensityDev="-1" AOBSIntensityLowDev="-1" EnableDoubleMode="0" IntensityDev="0" IntensityLowDev="0" IsLineChecked="0" IsLineDeactivated="0" IsVisible="0" LaserLine="472" LineIndex="2" OutCheckedIntensity="0" Qualifier="90" SequenceIndex="0" SuppressionMode="-1"/>
#   								<LaserLineSetting AOBSIntensityDev="-1" AOBSIntensityLowDev="-1" EnableDoubleMode="0" IntensityDev="0" IntensityLowDev="0" IsLineChecked="0" IsLineDeactivated="0" IsVisible="0" LaserLine="473" LineIndex="3" OutCheckedIntensity="0" Qualifier="90" SequenceIndex="0" SuppressionMode="-1"/>
#   								<LaserLineSetting AOBSIntensityDev="-1" AOBSIntensityLowDev="-1" EnableDoubleMode="0" IntensityDev="0" IntensityLowDev="0" IsLineChecked="0" IsLineDeactivated="0" IsVisible="0" LaserLine="667" LineIndex="4" OutCheckedIntensity="0" Qualifier="90" SequenceIndex="0" SuppressionMode="-1"/>
#   								<LaserLineSetting AOBSIntensityDev="-1" AOBSIntensityLowDev="-1" EnableDoubleMode="0" IntensityDev="0" IntensityLowDev="0" IsLineChecked="0" IsLineDeactivated="0" IsVisible="0" LaserLine="668" LineIndex="5" OutCheckedIntensity="0" Qualifier="90" SequenceIndex="0" SuppressionMode="-1"/>
#   								<LaserLineSetting AOBSIntensityDev="-1" AOBSIntensityLowDev="-1" EnableDoubleMode="0" IntensityDev="0" IntensityLowDev="0" IsLineChecked="0" IsLineDeactivated="0" IsVisible="0" LaserLine="669" LineIndex="6" OutCheckedIntensity="0" Qualifier="90" SequenceIndex="0" SuppressionMode="-1"/>
#   								<LaserLineSetting AOBSIntensityDev="-1" AOBSIntensityLowDev="-1" EnableDoubleMode="0" IntensityDev="0" IntensityLowDev="0" IsLineChecked="0" IsLineDeactivated="0" IsVisible="0" LaserLine="670" LineIndex="7" OutCheckedIntensity="0" Qualifier="90" SequenceIndex="0" SuppressionMode="-1"/>
#   							</Aotf>
#   							<Aotf AotfQualifier="10" AotfQualifierName="Visible" CanDoPulseFreq="0" CanDoTwoLaserPIE="0" IsChanged="0" LightSourceQualifier="10" LightSourceQualifierName="Vis" OpenVirtual="0" PulsFreq="0" TwoLaserPIEActive="0" TwoLaserPIEPossibleLastState="0">
#   								<LaserLineSetting AOBSIntensityDev="-1" AOBSIntensityLowDev="-1" EnableDoubleMode="0" IntensityDev="0" IntensityLowDev="0" IsLineChecked="1" IsLineDeactivated="0" IsVisible="1" LaserLine="458" LineIndex="0" OutCheckedIntensity="0" Qualifier="10" SequenceIndex="0" SuppressionMode="-1"/>
#   								<LaserLineSetting AOBSIntensityDev="-1" AOBSIntensityLowDev="-1" EnableDoubleMode="0" IntensityDev="0" IntensityLowDev="0" IsLineChecked="1" IsLineDeactivated="0" IsVisible="1" LaserLine="476" LineIndex="1" OutCheckedIntensity="0" Qualifier="10" SequenceIndex="0" SuppressionMode="-1"/>
#   								<LaserLineSetting AOBSIntensityDev="-1" AOBSIntensityLowDev="-1" EnableDoubleMode="0" IntensityDev="0" IntensityLowDev="0" IsLineChecked="1" IsLineDeactivated="0" IsVisible="1" LaserLine="488" LineIndex="2" OutCheckedIntensity="0" Qualifier="10" SequenceIndex="0" SuppressionMode="-1"/>
#   								<LaserLineSetting AOBSIntensityDev="-1" AOBSIntensityLowDev="-1" EnableDoubleMode="0" IntensityDev="0" IntensityLowDev="0" IsLineChecked="1" IsLineDeactivated="0" IsVisible="1" LaserLine="496" LineIndex="3" OutCheckedIntensity="0" Qualifier="10" SequenceIndex="0" SuppressionMode="-1"/>
#   								<LaserLineSetting AOBSIntensityDev="-1" AOBSIntensityLowDev="-1" EnableDoubleMode="0" IntensityDev="0" IntensityLowDev="0" IsLineChecked="1" IsLineDeactivated="0" IsVisible="1" LaserLine="514" LineIndex="4" OutCheckedIntensity="0" Qualifier="10" SequenceIndex="0" SuppressionMode="-1"/>
#   							</Aotf>
#   							<Aotf AotfQualifier="50" AotfQualifierName="MP" CanDoGainOffset="1" CanDoPulseFreq="0" CanDoTwoLaserPIE="0" ExcitationControlMode="0" ExcitationControlModeBegin="0" ExcitationControlModeEnd="0" Gain="0" IsChanged="0" LightSourceQualifier="40" LightSourceQualifierName="MP" Offset="80.2212558175021" OpenVirtual="0" PulsFreq="0" TwoLaserPIEActive="0" TwoLaserPIEPossibleLastState="0">
#   								<LaserLineSetting AOBSIntensityDev="-1" AOBSIntensityLowDev="-1" EnableDoubleMode="0" IntensityDev="0" IntensityLowDev="0" IsLineChecked="1" IsLineDeactivated="0" IsVisible="1" LaserLine="800" LineIndex="0" OutCheckedIntensity="0" Qualifier="50" SequenceIndex="0" SuppressionMode="-1"/>
#   							</Aotf>
#   						</AotfList>
#   						<LUT_List>
#   							<LUT Channel="1" LutName="Green"/>
#   							<LUT Channel="2" LutName="Red"/>
#   							<LUT Channel="3" LutName="Blue"/>
#   							<LUT Channel="4" LutName="Gray"/>
#   							<LUT Channel="1002" LutName="Red"/>
#   							<LUT Channel="1003" LutName="Green"/>
#   							<LUT Channel="1200" LutName="Red"/>
#   							<LUT Channel="1201" LutName="Green"/>
#   						</LUT_List>
#   						<DetectorList DetectorAutoSelection="1">
#   							<Detector AcquisitionMode="0" AcquisitionModeName="PhotonIntegration" CanDoPhotonCounting="1" CanDoTimeGate="1" Channel="1" ChannelName="Channel 1" Gain="10" IsActive="0" IsEnabled="0" IsFlimDetector="0" IsHPDDetector="1" IsHPDOverloaded="0" IsSTEDDetector="1" IsTimeGateActivated="0" Name="HyD 1" Offset="-6.6666666666606E-03" ScanType="Internal" TimeGatePulseEnd="6000" TimeGatePulseStart="300" TimeGateWavelength="470" Type="HyD"/>
#   							<Detector CanDoTimeGate="0" Channel="2" ChannelName="Channel 2" Gain="0" IsActive="1" IsFlimDetector="0" IsHPDDetector="0" IsSTEDDetector="1" Name="PMT 2" Offset="0" ScanType="Internal" Type="PMT"/>
#   							<Detector AcquisitionMode="0" AcquisitionModeName="PhotonIntegration" CanDoPhotonCounting="1" CanDoTimeGate="1" Channel="3" ChannelName="Channel 3" Gain="10" IsActive="0" IsEnabled="0" IsFlimDetector="0" IsHPDDetector="1" IsHPDOverloaded="0" IsSTEDDetector="1" IsTimeGateActivated="0" Name="HyD 3" Offset="-6.6666666666606E-03" ScanType="Internal" TimeGatePulseEnd="6000" TimeGatePulseStart="300" TimeGateWavelength="470" Type="HyD"/>
#   							<Detector CanDoTimeGate="0" Channel="4" ChannelName="Channel 4" Gain="0" IsActive="0" IsFlimDetector="0" IsHPDDetector="0" IsSTEDDetector="1" Name="PMT 4" Offset="0" ScanType="Internal" Type="PMT"/>
#   							<Detector CanDoTimeGate="0" Channel="1002" ChannelName="NDD3" Gain="0" IsActive="0" IsFlimDetector="0" IsHPDDetector="0" IsSTEDDetector="0" Name="PMT NDD3" Offset="0" ScanType="TLD" Type="PMT"/>
#   							<Detector CanDoTimeGate="0" Channel="1003" ChannelName="NDD4" Gain="0" IsActive="0" IsFlimDetector="0" IsHPDDetector="0" IsSTEDDetector="0" Name="PMT NDD4" Offset="0" ScanType="TLD" Type="PMT"/>
#   							<Detector AcquisitionMode="0" AcquisitionModeName="PhotonIntegration" CanDoPhotonCounting="1" CanDoTimeGate="0" Channel="1200" ChannelName="APD1" Gain="10" IsActive="0" IsEnabled="0" IsFlimDetector="0" IsHPDDetector="1" IsHPDOverloaded="0" IsSTEDDetector="0" Name="HyD6" Offset="-6.6666666666606E-03" ScanType="RLD" Type="HyD"/>
#   							<Detector AcquisitionMode="0" AcquisitionModeName="PhotonIntegration" CanDoPhotonCounting="1" CanDoTimeGate="0" Channel="1201" ChannelName="APD2" Gain="10" IsActive="0" IsEnabled="0" IsFlimDetector="0" IsHPDDetector="1" IsHPDOverloaded="0" IsSTEDDetector="0" Name="HyD7" Offset="-6.6666666666606E-03" ScanType="RLD" Type="HyD"/>
#   						</DetectorList>
#   						<LaserArray>
#   							<Laser CanDoChangeWavelength="0" CanDoLinearOutputPower="0" CanDoOutputPowerWatt="1" LaserName="405pulsed" LightSourceName="ChaserUV" LightSourceQualifier="60" OutputPowerWatt="0" PowerState="Off" Qualifier="80" QualifierName="ChaserUV" Wavelength="405"/>
#   							<Laser CanDoChangeWavelength="0" CanDoLinearOutputPower="1" CanDoOutputPowerWatt="0" LaserName="WLL" LightSourceName="SuperCont" LightSourceQualifier="70" OutputPower="0" OutputPowerMax="100" OutputPowerMin="0" PowerState="Off" PulsePickerRatio="0" Qualifier="90" QualifierName="WLL" Wavelength="0"/>
#   							<Laser CanDoChangeWavelength="0" CanDoLinearOutputPower="1" CanDoOutputPowerWatt="1" LaserName="Argon" LightSourceName="Vis" LightSourceQualifier="10" OutputPower="14" OutputPowerMax="140" OutputPowerMin="14" OutputPowerWatt="0" PowerState="Off" Qualifier="10" QualifierName="Visible" Wavelength="458"/>
#   							<Laser CanDoChangeWavelength="0" CanDoLinearOutputPower="0" CanDoOutputPowerWatt="1" LaserName="IR" LightSourceName="MP" LightSourceQualifier="40" OutputPowerWatt="2.02566914794911E-321" PowerState="Off" Qualifier="50" QualifierName="MP" Wavelength="800"/>
#   						</LaserArray>
#   						<ROI>
#   							<LMSDataContainerHeader Version="2">
#   								<Element Name="DCROISet" UniqueID="0cffdb83-9b07-11e4-9f85-bcf685d7650c">
#   									<Data>
#   										<ROISet PossibleChildROITypes="-1" PossibleROIActions="65535" PossibleROITransforms="65535" ROISetType="1"/>
#   									</Data>
#   									<Memory MemoryBlockID="MemBlock_26" Size="0"/>
#   									<Children/>
#   								</Element>
#   							</LMSDataContainerHeader>
#   						</ROI>
#   						<CompensationInterpolationPoints>
#   							<IntensityCompArray/>
#   						</CompensationInterpolationPoints>
#   						<OnlineDyeSeparation Channels="0" Detectors="0" Enabled="0" KeepRawImage="0" Normalize="0">
#   							<OnlineDyeSeparationDetectorList/>
#   							<OnlineDyeSeparationChannelList/>
#   						</OnlineDyeSeparation>
#   					</ATLConfocalSettingDefinition>
#   				</LDM_Block>
#   			</LDM_Block_Sequence_Block>
#   			<LDM_Block_Sequence_Block BlockID="8" BlockIsUsingCameraImageSource="0" BlockType="0">
#   				<LDM_Block BlockName="Job 2">
# - 					<ATLConfocalSettingDefinition ActiveCS_SubModeForRLD="0" ActiveCS_SubModeForRLDName="Empty" ActiveCS_SubModeForTLD="0" ActiveCS_SubModeForTLDName="Scan-BF" AdaptiveFocusControlActive="1" AdaptiveFocusControlAutonomousModeActive="0" AdaptiveFocusControlAutonomousOffset="-1" AotfValidBegin="0" AotfValidEnd="0" AreBleachPointsEnabled="0" AutoFocusMode="2" AutoFocusModeName="FirstChannelOnly" AutofocusChannel="1" AutofocusRedoEveryNTimePoints="0" BaseZoom="0.75" BitSize="8" CanDoCSMode="1" CanDoOpticalZoom="0" CanDoSTED="0" CompleteTime="3.96666666666667E-02" CycleCount="1" CycleTime="0" DetectorValidBegin="0" DetectorValidEnd="0" EmissionWavelengthForPinholeAiryCalculation="580" FrameAccumulation="1" FrameAverage="1" FrameTime="3.96666666666667E-02" Immersion="DRY" InDimension="16" InTrigger="-1" Is3DLimitedRoiScanEnable="0" IsAFCOnStart="0" IsAutofocusOnStart="0" IsConstantIntegrationTimeActive="1" IsFCSFilterAutomationActive="0" IsFastZStack="0" IsInverseMicroscopeModel="1" IsMPFormulaForStepSizerUsageActive="0" IsRoiScanEnable="0" IsSMDChaserUVAOTFAutomationActive="0" IsSTEDActive="0" IsSuperZ="0" IsTimeMinimizeEnabled="0" IsUserSettingNameSet="0" IsZStackAroundCurrent="0" LambdaExcitationMode="0" LambdaExcitationModeBegin="0" LambdaExcitationModeEnd="0" LastNonMP_MFP_FW_Name="Substrate " LastNonMP_Pol_FW_Name="Empty" LastTCalcMode="3" Limited3DRoiFirstSection="1" Limited3DRoiLastSection="1" LineAverage="1" LineTime="1.66666666666667E-03" Line_Accumulation="1" Lines="512" Magnification="20" MaxLines="1" MicroscopeModel="DMI6000B-CS" MotCorrPosDevBegin="-1" MotCorrPosDevEnd="-1" MotCorrPosition="6.62037037037037" MotCorrSlotIndexBegin="-1" MotCorrSlotIndexEnd="-1" MotCorrValidBegin="0" MotCorrValidEnd="0" NumericalAperture="0.75" ObjectiveName="HCX PL APO CS    20x/0.75 DRY " ObjectiveNumber="11506517" ObjectivePos="1" OpticalZoom="1" OutDimension="16" OutTrigger="-1" Pages="1" PanFirstDim="8.67361737988404E-19" PanSecondDim="8.67361737988404E-19" Pinhole="5.66408184255765E-05" PinholeAiry="1.00057974889727" PixelDwellTime="0.000026025" RefractionIndex="1" RotatorAngle="0" STEDDelayTimeOffset="0" STEDDelayTimeOffset2="0" ScanDirectionX="1" ScanDirectionXName="Unidirectional" ScanMode="xyz" ScanSpeed="600" Sections="1" StackCalculationMode="2" StackCalculationModeName="System optimized step size" StagePosX="0.04010200095214" StagePosY="0.03092499881483" StageRangeX="0.11279375084332" StageRangeY="0.07937695154648" SystemSerialNumber="8100000303" UseMaxIterationsForT="0" UseScanFormatRestriction="0" UseSystemOptimizedVoxelCalculation="1" UserSettingName="S7" ValidBeginStack="0" ValidEndStack="0" VersionNumber="6" ZIntensityCompensationMode="0" ZIntensityCompensationModeName="None" ZPosition="-2.3841880645312E-10" ZStackDirectionMode="1" ZStackDirectionModeName="Unidirectional" ZUseMode="1" ZUseModeName="z-galvo" Zoom="1">
# ? 					                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ^^^^^^^^  ^                  ^^    ^^^^^
#
# + 					<ATLConfocalSettingDefinition ActiveCS_SubModeForRLD="0" ActiveCS_SubModeForRLDName="Empty" ActiveCS_SubModeForTLD="0" ActiveCS_SubModeForTLDName="Scan-BF" AdaptiveFocusControlActive="1" AdaptiveFocusControlAutonomousModeActive="0" AdaptiveFocusControlAutonomousOffset="-1" AotfValidBegin="0" AotfValidEnd="0" AreBleachPointsEnabled="0" AutoFocusMode="2" AutoFocusModeName="FirstChannelOnly" AutofocusChannel="1" AutofocusRedoEveryNTimePoints="0" BaseZoom="0.75" BitSize="8" CanDoCSMode="1" CanDoOpticalZoom="0" CanDoSTED="0" CompleteTime="3.96666666666667E-02" CycleCount="1" CycleTime="0" DetectorValidBegin="0" DetectorValidEnd="0" EmissionWavelengthForPinholeAiryCalculation="580" FrameAccumulation="1" FrameAverage="1" FrameTime="3.96666666666667E-02" Immersion="DRY" InDimension="16" InTrigger="-1" Is3DLimitedRoiScanEnable="0" IsAFCOnStart="0" IsAutofocusOnStart="0" IsConstantIntegrationTimeActive="1" IsFCSFilterAutomationActive="0" IsFastZStack="0" IsInverseMicroscopeModel="1" IsMPFormulaForStepSizerUsageActive="0" IsRoiScanEnable="0" IsSMDChaserUVAOTFAutomationActive="0" IsSTEDActive="0" IsSuperZ="0" IsTimeMinimizeEnabled="0" IsUserSettingNameSet="0" IsZStackAroundCurrent="0" LambdaExcitationMode="0" LambdaExcitationModeBegin="0" LambdaExcitationModeEnd="0" LastNonMP_MFP_FW_Name="Substrate " LastNonMP_Pol_FW_Name="Empty" LastTCalcMode="3" Limited3DRoiFirstSection="1" Limited3DRoiLastSection="1" LineAverage="1" LineTime="1.66666666666667E-03" Line_Accumulation="1" Lines="512" Magnification="20" MaxLines="1" MicroscopeModel="DMI6000B-CS" MotCorrPosDevBegin="-1" MotCorrPosDevEnd="-1" MotCorrPosition="6.62037037037037" MotCorrSlotIndexBegin="-1" MotCorrSlotIndexEnd="-1" MotCorrValidBegin="0" MotCorrValidEnd="0" NumericalAperture="0.75" ObjectiveName="HCX PL APO CS    20x/0.75 DRY " ObjectiveNumber="11506517" ObjectivePos="1" OpticalZoom="1" OutDimension="16" OutTrigger="-1" Pages="1" PanFirstDim="8.67361737988404E-19" PanSecondDim="8.67361737988404E-19" Pinhole="5.66408184255765E-05" PinholeAiry="1.00057974889727" PixelDwellTime="0.000026025" RefractionIndex="1" RotatorAngle="0" STEDDelayTimeOffset="0" STEDDelayTimeOffset2="0" ScanDirectionX="1" ScanDirectionXName="Unidirectional" ScanMode="xyz" ScanSpeed="600" Sections="1" StackCalculationMode="2" StackCalculationModeName="System optimized step size" StagePosX="0.04175200010734" StagePosY="0.03322499763723" StageRangeX="0.11279375084332" StageRangeY="0.07937695154648" SystemSerialNumber="8100000303" UseMaxIterationsForT="0" UseScanFormatRestriction="0" UseSystemOptimizedVoxelCalculation="1" UserSettingName="S7" ValidBeginStack="0" ValidEndStack="0" VersionNumber="6" ZIntensityCompensationMode="0" ZIntensityCompensationModeName="None" ZPosition="-2.3841880645312E-10" ZStackDirectionMode="1" ZStackDirectionModeName="Unidirectional" ZUseMode="1" ZUseModeName="z-galvo" Zoom="1">
# ? 					                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ^^  ^^^^^^^                  ^^    ^^^^^
#
#   						<EasySRMappingArray/>
#   						<EasySRSlider GentleRelative="25" SRRelative="75" ThreeDRelative="0"/>
#   						<Quantity Unit="" Value="0"/>
#   						<AdditionalZPositionList>
#   							<AdditionalZPosition SuperZMode="1" SuperZModeName="RestrictedRange" Valid="1" ZMode="1" ZPosition="-2.3841880645312E-10" ZUseModeName="z-galvo"/>
#   							<AdditionalZPosition SuperZMode="1" SuperZModeName="RestrictedRange" Valid="1" ZMode="2" ZPosition="0" ZUseModeName="z-wide"/>
#   						</AdditionalZPositionList>
#   						<Autofocus-config AFAnalyseType="1" AFAnalyseTypeName="EveryChannel" AFCOffset="-2" AFSubsystem="0" AFSubsystemName="BaseAF" FocusRange="0.00008" Precision="2" UseFixSliceNumber="0" WorkflowTimelapse="1" WorkflowTimelapseIterator="1" WorkflowTimelapseName="FirstTime" WorkflowXY="1" WorkflowXYIterator="1" WorkflowXYName="FirstPos" ZUseMode="1" ZUseModeName="z-galvo"/>
#   						<ShutterList>
#   							<Shutter IsActive="0" LightSourceName="ChaserUV" LightSourceQualifier="60" ShutterName="ChaserUV" ShutterQualifier="6"/>
#   							<Shutter IsActive="0" LightSourceName="SuperCont" LightSourceQualifier="70" ShutterName="WLL" ShutterQualifier="8"/>
#   							<Shutter IsActive="0" LightSourceName="Vis" LightSourceQualifier="10" ShutterName="Visible" ShutterQualifier="3"/>
#   							<Shutter IsActive="0" LightSourceName="MP" LightSourceQualifier="40" ShutterName="MP" ShutterQualifier="4"/>
#   						</ShutterList>
#   						<BleachPoints>
#   							<LMSDataContainerHeader Version="2">
#   								<Element Name="BleachPointROISet" UniqueID="0cffdb86-9b07-11e4-9f85-bcf685d7650c">
#   									<Data>
#   										<ROISet PossibleChildROITypes="-1" PossibleROIActions="65535" PossibleROITransforms="65535" ROISetType="1"/>
#   									</Data>
#   									<Memory MemoryBlockID="MemBlock_31" Size="0"/>
#   									<Children/>
#   								</Element>
#   							</LMSDataContainerHeader>
#   						</BleachPoints>
#   						<ATLConfocalBleachPointsSettings/>
#   						<FilterWheel BeamSplitterAutoSelection="0" FluorifierAutoSelection="1" StedBeamSelectionPinholeCoupling="0">
#   							<Wheel FilterIndex="0" FilterName="Min" FilterSpectrumPos="3000" FilterWheelName="Attenuation MP" IndexChanged="0" IsSpectrumTurnMode="0" LightSourceQualifier="40" Qualifier="214" SpectrumChanged="0">
#   								<WheelName FilterName="Min"/>
#   								<WheelName FilterName="Max"/>
#   							</Wheel>
#   							<Wheel FilterIndex="2" FilterName="Mirror " FilterSpectrumPos="0" FilterWheelName="External Detection FW" IndexChanged="0" IsSpectrumTurnMode="0" Qualifier="140" SpectrumChanged="0">
#   								<WheelName FilterName="--- "/>
#   								<WheelName FilterName="Substrate "/>
#   								<WheelName FilterName="Mirror "/>
#   							</Wheel>
#   							<Wheel FilterIndex="0" FilterName="--- " FilterSpectrumPos="0" FilterWheelName="FCS-FW" IndexChanged="0" IsSpectrumTurnMode="0" Qualifier="26" SpectrumChanged="0">
#   								<WheelName FilterName="--- "/>
#   								<WheelName FilterName="CleaningFilter 458"/>
#   								<WheelName FilterName="CleaningFilter 488"/>
#   								<WheelName FilterName="CleaningFilter 514"/>
#   								<WheelName FilterName="CleaningFilter 458/514"/>
#   								<WheelName FilterName="--- "/>
#   								<WheelName FilterName="--- "/>
#   								<WheelName FilterName="--- "/>
#   							</Wheel>
#   							<Wheel FilterIndex="0" FilterName="Galvo X Normal " FilterSpectrumPos="0" FilterWheelName="Galvo Slider" IndexChanged="0" IsSpectrumTurnMode="0" Qualifier="160" SpectrumChanged="0">
#   								<WheelName FilterName="Galvo X Normal "/>
#   								<WheelName FilterName="Galvo X Res "/>
#   							</Wheel>
#   							<Wheel FilterIndex="4" FilterName="Substrate " FilterSpectrumPos="0" FilterWheelName="Multi Function Port" IndexChanged="0" IsSpectrumTurnMode="0" Qualifier="180" SpectrumChanged="0">
#   								<WheelName FilterName="--- "/>
#   								<WheelName FilterName="SP 815"/>
#   								<WheelName FilterName="SP 665"/>
#   								<WheelName FilterName="Mirror "/>
#   								<WheelName FilterName="Substrate "/>
#   							</Wheel>
#   							<Wheel FilterIndex="0" FilterName="Empty" FilterSpectrumPos="0" FilterWheelName="Notch FW 2" IndexChanged="0" IsSpectrumTurnMode="0" Qualifier="131" SpectrumChanged="0">
#   								<WheelName FilterName="Empty"/>
#   								<WheelName FilterName="--- "/>
#   								<WheelName FilterName="--- "/>
#   								<WheelName FilterName="--- "/>
#   								<WheelName FilterName="--- "/>
#   								<WheelName FilterName="--- "/>
#   								<WheelName FilterName="--- "/>
#   								<WheelName FilterName="MP1 SP 680"/>
#   								<WheelName FilterName="--- "/>
#   								<WheelName FilterName="OPO SP 800"/>
#   								<WheelName FilterName="SMD1 NF 405/470"/>
#   								<WheelName FilterName="SMD2 NF 405/640"/>
#   								<WheelName FilterName="SMD3 NF 470/640"/>
#   								<WheelName FilterName="--- "/>
#   							</Wheel>
#   							<Wheel FilterIndex="0" FilterName="Empty" FilterSpectrumPos="79246" FilterWheelName="Polarization FW" IndexChanged="0" IsSpectrumTurnMode="0" Qualifier="130" SpectrumChanged="0">
#   								<WheelName FilterName="Empty"/>
#   								<WheelName FilterName="NF 488"/>
#   								<WheelName FilterName="NF 514"/>
#   								<WheelName FilterName="NF 458/514"/>
#   								<WheelName FilterName="NF 488/561/633"/>
#   								<WheelName FilterName="--- "/>
#   							</Wheel>
#   							<Wheel FilterIndex="0" FilterName="Galvo X Pan Center " FilterSpectrumPos="0" FilterWheelName="Galvo Resonant Pan" IndexChanged="0" IsSpectrumTurnMode="0" Qualifier="200" SpectrumChanged="0">
#   								<WheelName FilterName="Galvo X Pan Center "/>
#   								<WheelName FilterName="Galvo X Pan Mirror "/>
#   								<WheelName FilterName="Galvo X Pan Polfilter "/>
#   								<WheelName FilterName="Galvo X Pan RefDiode "/>
#   							</Wheel>
#   							<Wheel FilterIndex="0" FilterName="Target Park " FilterSpectrumPos="0" FilterWheelName="Target Slider" IndexChanged="0" IsSpectrumTurnMode="0" Qualifier="170" SpectrumChanged="0">
#   								<WheelName FilterName="Target Park "/>
#   								<WheelName FilterName="Target Inserted "/>
#   								<WheelName FilterName="Target Mirror "/>
#   							</Wheel>
#   							<Wheel FilterIndex="0" FilterName="CS2 UV Optics 1 " FilterSpectrumPos="0" FilterWheelName="X2 Lens Changer" IndexChanged="0" IsSpectrumTurnMode="0" Qualifier="31" SpectrumChanged="0">
#   								<WheelName FilterName="CS2 UV Optics 1 "/>
#   								<WheelName FilterName="CS2 UV Optics 2 "/>
#   							</Wheel>
#   						</FilterWheel>
#   						<Spectro>
#   							<MultiBand Channel="1" ChannelName="Channel 1" DyeName="" LeftWorld="406.25" RightWorld="458.75"/>
#   							<MultiBand Channel="2" ChannelName="Channel 2" DyeName="" LeftWorld="511.25" RightWorld="563.75"/>
#   							<MultiBand Channel="3" ChannelName="Channel 3" DyeName="" LeftWorld="616.25" RightWorld="668.75"/>
#   							<MultiBand Channel="4" ChannelName="Channel 4" DyeName="" LeftWorld="721.25" RightWorld="773.75"/>
#   						</Spectro>
#   						<AotfList>
#   							<Aotf AotfQualifier="80" AotfQualifierName="ChaserUV" CanDoPulseFreq="1" CanDoTwoLaserPIE="0" IsChanged="0" LightSourceQualifier="60" LightSourceQualifierName="ChaserUV" OpenVirtual="0" PulsFreq="40000000" TwoLaserPIEActive="0" TwoLaserPIEPossibleLastState="0">
#   								<LaserLineSetting AOBSIntensityDev="-1" AOBSIntensityLowDev="-1" EnableDoubleMode="0" IntensityDev="0" IntensityLowDev="0" IsLineChecked="1" IsLineDeactivated="0" IsVisible="1" LaserLine="405" LineIndex="0" OutCheckedIntensity="0" Qualifier="80" SequenceIndex="0" SuppressionMode="-1"/>
#   							</Aotf>
#   							<Aotf AotfQualifier="90" AotfQualifierName="WLL" CanDoPulseFreq="0" CanDoTwoLaserPIE="0" ExcitationControlMode="0" ExcitationControlModeBegin="0" ExcitationControlModeEnd="0" IsChanged="0" LightSourceQualifier="70" LightSourceQualifierName="SuperCont" OpenVirtual="0" PulsFreq="0" TwoLaserPIEActive="0" TwoLaserPIEPossibleLastState="0">
#   								<LaserLineSetting AOBSIntensityDev="-1" AOBSIntensityLowDev="-1" EnableDoubleMode="0" IntensityDev="0" IntensityLowDev="0" IsLineChecked="0" IsLineDeactivated="0" IsVisible="1" LaserLine="470" LineIndex="0" OutCheckedIntensity="0" Qualifier="90" SequenceIndex="0" SuppressionMode="-1"/>
#   								<LaserLineSetting AOBSIntensityDev="-1" AOBSIntensityLowDev="-1" EnableDoubleMode="0" IntensityDev="0" IntensityLowDev="0" IsLineChecked="0" IsLineDeactivated="0" IsVisible="0" LaserLine="471" LineIndex="1" OutCheckedIntensity="0" Qualifier="90" SequenceIndex="0" SuppressionMode="-1"/>
#   								<LaserLineSetting AOBSIntensityDev="-1" AOBSIntensityLowDev="-1" EnableDoubleMode="0" IntensityDev="0" IntensityLowDev="0" IsLineChecked="0" IsLineDeactivated="0" IsVisible="0" LaserLine="472" LineIndex="2" OutCheckedIntensity="0" Qualifier="90" SequenceIndex="0" SuppressionMode="-1"/>
#   								<LaserLineSetting AOBSIntensityDev="-1" AOBSIntensityLowDev="-1" EnableDoubleMode="0" IntensityDev="0" IntensityLowDev="0" IsLineChecked="0" IsLineDeactivated="0" IsVisible="0" LaserLine="473" LineIndex="3" OutCheckedIntensity="0" Qualifier="90" SequenceIndex="0" SuppressionMode="-1"/>
#   								<LaserLineSetting AOBSIntensityDev="-1" AOBSIntensityLowDev="-1" EnableDoubleMode="0" IntensityDev="0" IntensityLowDev="0" IsLineChecked="0" IsLineDeactivated="0" IsVisible="0" LaserLine="667" LineIndex="4" OutCheckedIntensity="0" Qualifier="90" SequenceIndex="0" SuppressionMode="-1"/>
#   								<LaserLineSetting AOBSIntensityDev="-1" AOBSIntensityLowDev="-1" EnableDoubleMode="0" IntensityDev="0" IntensityLowDev="0" IsLineChecked="0" IsLineDeactivated="0" IsVisible="0" LaserLine="668" LineIndex="5" OutCheckedIntensity="0" Qualifier="90" SequenceIndex="0" SuppressionMode="-1"/>
#   								<LaserLineSetting AOBSIntensityDev="-1" AOBSIntensityLowDev="-1" EnableDoubleMode="0" IntensityDev="0" IntensityLowDev="0" IsLineChecked="0" IsLineDeactivated="0" IsVisible="0" LaserLine="669" LineIndex="6" OutCheckedIntensity="0" Qualifier="90" SequenceIndex="0" SuppressionMode="-1"/>
#   								<LaserLineSetting AOBSIntensityDev="-1" AOBSIntensityLowDev="-1" EnableDoubleMode="0" IntensityDev="0" IntensityLowDev="0" IsLineChecked="0" IsLineDeactivated="0" IsVisible="0" LaserLine="670" LineIndex="7" OutCheckedIntensity="0" Qualifier="90" SequenceIndex="0" SuppressionMode="-1"/>
#   							</Aotf>
#   							<Aotf AotfQualifier="10" AotfQualifierName="Visible" CanDoPulseFreq="0" CanDoTwoLaserPIE="0" IsChanged="0" LightSourceQualifier="10" LightSourceQualifierName="Vis" OpenVirtual="0" PulsFreq="0" TwoLaserPIEActive="0" TwoLaserPIEPossibleLastState="0">
#   								<LaserLineSetting AOBSIntensityDev="-1" AOBSIntensityLowDev="-1" EnableDoubleMode="0" IntensityDev="0" IntensityLowDev="0" IsLineChecked="1" IsLineDeactivated="0" IsVisible="1" LaserLine="458" LineIndex="0" OutCheckedIntensity="0" Qualifier="10" SequenceIndex="0" SuppressionMode="-1"/>
#   								<LaserLineSetting AOBSIntensityDev="-1" AOBSIntensityLowDev="-1" EnableDoubleMode="0" IntensityDev="0" IntensityLowDev="0" IsLineChecked="1" IsLineDeactivated="0" IsVisible="1" LaserLine="476" LineIndex="1" OutCheckedIntensity="0" Qualifier="10" SequenceIndex="0" SuppressionMode="-1"/>
#   								<LaserLineSetting AOBSIntensityDev="-1" AOBSIntensityLowDev="-1" EnableDoubleMode="0" IntensityDev="0" IntensityLowDev="0" IsLineChecked="1" IsLineDeactivated="0" IsVisible="1" LaserLine="488" LineIndex="2" OutCheckedIntensity="0" Qualifier="10" SequenceIndex="0" SuppressionMode="-1"/>
#   								<LaserLineSetting AOBSIntensityDev="-1" AOBSIntensityLowDev="-1" EnableDoubleMode="0" IntensityDev="0" IntensityLowDev="0" IsLineChecked="1" IsLineDeactivated="0" IsVisible="1" LaserLine="496" LineIndex="3" OutCheckedIntensity="0" Qualifier="10" SequenceIndex="0" SuppressionMode="-1"/>
#   								<LaserLineSetting AOBSIntensityDev="-1" AOBSIntensityLowDev="-1" EnableDoubleMode="0" IntensityDev="0" IntensityLowDev="0" IsLineChecked="1" IsLineDeactivated="0" IsVisible="1" LaserLine="514" LineIndex="4" OutCheckedIntensity="0" Qualifier="10" SequenceIndex="0" SuppressionMode="-1"/>
#   							</Aotf>
#   							<Aotf AotfQualifier="50" AotfQualifierName="MP" CanDoGainOffset="1" CanDoPulseFreq="0" CanDoTwoLaserPIE="0" ExcitationControlMode="0" ExcitationControlModeBegin="0" ExcitationControlModeEnd="0" Gain="0" IsChanged="0" LightSourceQualifier="40" LightSourceQualifierName="MP" Offset="80.2212558175021" OpenVirtual="0" PulsFreq="0" TwoLaserPIEActive="0" TwoLaserPIEPossibleLastState="0">
#   								<LaserLineSetting AOBSIntensityDev="-1" AOBSIntensityLowDev="-1" EnableDoubleMode="0" IntensityDev="0" IntensityLowDev="0" IsLineChecked="1" IsLineDeactivated="0" IsVisible="1" LaserLine="800" LineIndex="0" OutCheckedIntensity="0" Qualifier="50" SequenceIndex="0" SuppressionMode="-1"/>
#   							</Aotf>
#   						</AotfList>
#   						<LUT_List>
#   							<LUT Channel="1" LutName="Green"/>
#   							<LUT Channel="2" LutName="Red"/>
#   							<LUT Channel="3" LutName="Blue"/>
#   							<LUT Channel="4" LutName="Gray"/>
#   							<LUT Channel="1002" LutName="Red"/>
#   							<LUT Channel="1003" LutName="Green"/>
#   							<LUT Channel="1200" LutName="Red"/>
#   							<LUT Channel="1201" LutName="Green"/>
#   						</LUT_List>
#   						<DetectorList DetectorAutoSelection="1">
#   							<Detector AcquisitionMode="0" AcquisitionModeName="PhotonIntegration" CanDoPhotonCounting="1" CanDoTimeGate="1" Channel="1" ChannelName="Channel 1" Gain="10" IsActive="0" IsEnabled="0" IsFlimDetector="0" IsHPDDetector="1" IsHPDOverloaded="0" IsSTEDDetector="1" IsTimeGateActivated="0" Name="HyD 1" Offset="-6.6666666666606E-03" ScanType="Internal" TimeGatePulseEnd="6000" TimeGatePulseStart="300" TimeGateWavelength="470" Type="HyD"/>
#   							<Detector CanDoTimeGate="0" Channel="2" ChannelName="Channel 2" Gain="0" IsActive="1" IsFlimDetector="0" IsHPDDetector="0" IsSTEDDetector="1" Name="PMT 2" Offset="0" ScanType="Internal" Type="PMT"/>
#   							<Detector AcquisitionMode="0" AcquisitionModeName="PhotonIntegration" CanDoPhotonCounting="1" CanDoTimeGate="1" Channel="3" ChannelName="Channel 3" Gain="10" IsActive="0" IsEnabled="0" IsFlimDetector="0" IsHPDDetector="1" IsHPDOverloaded="0" IsSTEDDetector="1" IsTimeGateActivated="0" Name="HyD 3" Offset="-6.6666666666606E-03" ScanType="Internal" TimeGatePulseEnd="6000" TimeGatePulseStart="300" TimeGateWavelength="470" Type="HyD"/>
#   							<Detector CanDoTimeGate="0" Channel="4" ChannelName="Channel 4" Gain="0" IsActive="0" IsFlimDetector="0" IsHPDDetector="0" IsSTEDDetector="1" Name="PMT 4" Offset="0" ScanType="Internal" Type="PMT"/>
#   							<Detector CanDoTimeGate="0" Channel="1002" ChannelName="NDD3" Gain="0" IsActive="0" IsFlimDetector="0" IsHPDDetector="0" IsSTEDDetector="0" Name="PMT NDD3" Offset="0" ScanType="TLD" Type="PMT"/>
#   							<Detector CanDoTimeGate="0" Channel="1003" ChannelName="NDD4" Gain="0" IsActive="0" IsFlimDetector="0" IsHPDDetector="0" IsSTEDDetector="0" Name="PMT NDD4" Offset="0" ScanType="TLD" Type="PMT"/>
#   							<Detector AcquisitionMode="0" AcquisitionModeName="PhotonIntegration" CanDoPhotonCounting="1" CanDoTimeGate="0" Channel="1200" ChannelName="APD1" Gain="10" IsActive="0" IsEnabled="0" IsFlimDetector="0" IsHPDDetector="1" IsHPDOverloaded="0" IsSTEDDetector="0" Name="HyD6" Offset="-6.6666666666606E-03" ScanType="RLD" Type="HyD"/>
#   							<Detector AcquisitionMode="0" AcquisitionModeName="PhotonIntegration" CanDoPhotonCounting="1" CanDoTimeGate="0" Channel="1201" ChannelName="APD2" Gain="10" IsActive="0" IsEnabled="0" IsFlimDetector="0" IsHPDDetector="1" IsHPDOverloaded="0" IsSTEDDetector="0" Name="HyD7" Offset="-6.6666666666606E-03" ScanType="RLD" Type="HyD"/>
#   						</DetectorList>
#   						<LaserArray>
#   							<Laser CanDoChangeWavelength="0" CanDoLinearOutputPower="0" CanDoOutputPowerWatt="1" LaserName="405pulsed" LightSourceName="ChaserUV" LightSourceQualifier="60" OutputPowerWatt="0" PowerState="Off" Qualifier="80" QualifierName="ChaserUV" Wavelength="405"/>
#   							<Laser CanDoChangeWavelength="0" CanDoLinearOutputPower="1" CanDoOutputPowerWatt="0" LaserName="WLL" LightSourceName="SuperCont" LightSourceQualifier="70" OutputPower="0" OutputPowerMax="100" OutputPowerMin="0" PowerState="Off" PulsePickerRatio="0" Qualifier="90" QualifierName="WLL" Wavelength="0"/>
#   							<Laser CanDoChangeWavelength="0" CanDoLinearOutputPower="1" CanDoOutputPowerWatt="1" LaserName="Argon" LightSourceName="Vis" LightSourceQualifier="10" OutputPower="14" OutputPowerMax="140" OutputPowerMin="14" OutputPowerWatt="0" PowerState="Off" Qualifier="10" QualifierName="Visible" Wavelength="458"/>
#   							<Laser CanDoChangeWavelength="0" CanDoLinearOutputPower="0" CanDoOutputPowerWatt="1" LaserName="IR" LightSourceName="MP" LightSourceQualifier="40" OutputPowerWatt="2.02566914794911E-321" PowerState="Off" Qualifier="50" QualifierName="MP" Wavelength="800"/>
#   						</LaserArray>
#   						<ROI>
#   							<LMSDataContainerHeader Version="2">
#   								<Element Name="DCROISet" UniqueID="0cffdb85-9b07-11e4-9f85-bcf685d7650c">
#   									<Data>
#   										<ROISet PossibleChildROITypes="-1" PossibleROIActions="65535" PossibleROITransforms="65535" ROISetType="1"/>
#   									</Data>
#   									<Memory MemoryBlockID="MemBlock_30" Size="0"/>
#   									<Children/>
#   								</Element>
#   							</LMSDataContainerHeader>
#   						</ROI>
#   						<CompensationInterpolationPoints>
#   							<IntensityCompArray/>
#   						</CompensationInterpolationPoints>
#   						<OnlineDyeSeparation Channels="0" Detectors="0" Enabled="0" KeepRawImage="0" Normalize="0">
#   							<OnlineDyeSeparationDetectorList/>
#   							<OnlineDyeSeparationChannelList/>
#   						</OnlineDyeSeparation>
#   					</ATLConfocalSettingDefinition>
#   				</LDM_Block>
#   			</LDM_Block_Sequence_Block>
#   		</LDM_Block_Sequence_Block_List>
#   	</LDM_Block_Sequence>
#   </Configuration>
