# %%
# %pylab inline
from skimage import io
import matrixscreener

unadjusted = matrixscreener.experiment.Experiment('/Users/arve/Dokumenter/TFY4500/unstained/experiment--row 0-2/')
img_path = unadjusted.images[0]
img = io.imread(img_path)

imshow(img);
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/arve/.virtualenvs/3.4/lib/python3.4/site-packages/tifffile.py:1149: UserWarning: ome-xml: invalid TiffData index
#   warnings.warn("ome-xml: invalid TiffData index")

# %%
for line in img:
    plot(line)
xlim((0,1024))
# Out:
# (0, 1024)
