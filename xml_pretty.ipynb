# %%
import xml.dom.minidom

dom = xml.dom.minidom.parse('{ScanningTemplate}asdf.lrp')
print(dom.toprettyxml('  '))
# Out:
# <?xml version="1.0" ?>
# <!--Leica Application Suite X (LAS X)-->
# <!--Leica Microsystems CMS GmbH-->
# <!--http://www.confocal-microscopy.com-->
# <!--LAS-AF 1.1.0.12420-->
# <Configuration ID="2271935676" SystemType="-1" Type="7">
#   <LDM_Block_Sequence BlockName="collecting pattern">
#     <LDM_Block_Sequence_Element_List>
# ...

# %%
fp = open('{ScanningTemplate}asdf.lrp.pretty.xml', 'w')

# %%
fp.write(dom.toprettyxml('  '))
fp.close()
