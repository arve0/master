# %%
from leicaexperiment import Experiment

path = r'D:\MatrixScreenerImages\3.3.0_9757'
path += '\\'
e = Experiment(path + 'experiment--2015_04_29_12_04_39')

# %%
import imreg_dft as imreg
from skimage import io

# %%
rows = e.rows(0,0)
cols = e.columns(0,0)
rows, cols
# Out:
# ([0], [0, 1])

# %%
p1 = e.image(0,0,0,0)
p2 = e.image(0,0,1,0)
img1 = io.imread(p1)
img2 = io.imread(p2)
translation = imreg.translation(img1, img2)

# %%
translation
# Out:
# (array([-2352,   -95], dtype=int64), 0.0013073616640258334)

# %%
imreg.similarity(img1, img2)
# Out:
# {'Dangle': 0.010986328125,
#  'Dscale': 0.00051375719514212825,
#  'Dt': 0.5,
#  'angle': -180.0,
#  'scale': 1.0,
#  'success': 0.0013324628485737668,
#  'timg': array([[ 92.57668104,  93.2619413 ,  93.90108872, ...,  93.15868644,
#           93.05639264,  92.79660485],
#         [ 93.10546226,  93.25243264,  93.41382871, ...,  93.18988177,
#           93.15237809,  93.10208336],
#         [ 93.22127635,  93.27383332,  93.33826125, ...,  93.2131271 ,
#           93.20450911,  93.20132709],
#         ...,
#         [ 93.        ,  94.        ,  99.        , ...,  93.18999208,
#           93.14701025,  93.06579741],
#         [ 89.        ,  89.        ,  94.        , ...,  93.14440304,
#           92.9684063 ,  92.19288497],
#         [ 88.        ,  96.        ,  98.        , ...,  93.13472498,
#           92.95256605,  92.24735668]]),
#  'tvec': array([  963, -1391], dtype=int64)}

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['e']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
figure(figsize=(16,8))
subplot(121)
io.imshow(p1)
subplot(122)
io.imshow(p2);
