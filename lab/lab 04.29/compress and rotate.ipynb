# %%
# %matplotlib inline
from leicaexperiment import Experiment
from skimage import io

# %%
path = r'D:\MatrixScreenerImages\3.3.0_9757'
path += '\\'

# %%
e = Experiment(path + 'experiment--2015_04_29_12_04_39')
io.imshow(e.image(0,0,0,0))

# %%
e.compress(delete_tif=True);

# %%
from PIL import Image
for i in e.images:
    img = Image.open(i)
    img = img.rotate(270)
    img.save(i)

# %%
io.imshow(e.image(0,0,0,0))
