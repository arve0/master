# %%
def s():
    "display screenshot"
    from IPython.display import Image
    return Image('../Capture.PNG')

# %%
s()

# %%
# open LAS X
s()

# %%
# open matrixscreener
s()

# %%
s()

# %%
s()

# %%
s()

# %%
s()

# %%
s()

# %%
s()

# %%
s()

# %%
from leicacam import CAM

# %%
cam = CAM()

# %%
cam.get_information()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-f2cf58e81da3> in <module>()
# ----> 1 cam.get_information()
#
# c:\users\tcs-user\downloads\leicacam\leicacam\cam.py in get_information(self, about)
#     176         ]
#     177         response = self.send(cmd)
# --> 178         if len(response) == 0:
#     179             return None
#     180         else:
#
# TypeError: object of type 'NoneType' has no len()

# %%
cam.receive()
# Out:
# [OrderedDict([('app', 'matrix'), ('sys', '0'), ('dev', 'stage'), ('info_for', 'python-matrixscreener'), ('unit', 'meter'), ('xpos', '0.0594239979'), ('ypos', '0.0298620013'), ('zpos', '-0.0000000002')]),
#  OrderedDict([('cli', 'python-matrixscreener'), ('app', 'matrix'), ('cmd', 'getinfo'), ('dev', 'stage')])]

# %%
from leicascanningtemplate import ScanningTemplate

# %%
p = b"C:\Users\TCS-User\AppData\Roaming\Leica Microsystems\LAS X\MatrixScreener\ScanningTemplates".decode()
f = p + b"\{ScanningTemplate}new.xml".decode()
tmpl = ScanningTemplate(f)

# %%
x,y = float(tmpl.well().attrib['FieldXStartCoordinate']), float(tmpl.well().attrib['FieldYStartCoordinate'])
x,y
# Out:
# (0.06452399999999998, 0.034962)

# %%
tmpl.move_well(1,1,x+1700e-6,y+1700e-6)

# %%
x,y = float(tmpl.well().attrib['FieldXStartCoordinate']), float(tmpl.well().attrib['FieldYStartCoordinate'])
x,y
# Out:
# (0.06452399999999998, 0.034962)

# %%
tmpl.write()

# %%
cam.load_template(r'{ScanningTemplate}whole2')

# %% [markdown]
# - work around LAS not loading template

# %%
cam.load_template(r'{ScanningTemplate}new')

# %%
cam.start_scan()

# %% [markdown]
# - this works, but gives about 30-60 seconds extra per well
