# %% [markdown]
# # loading templates through CAM

# %%
from leicacam import CAM

# %%
cam = CAM()

# %%
cam.load_template(r'{ScanningTemplate}leicascanningtemplate')

# %%
cam.receive()
# Out:
# [OrderedDict([('cli', 'python-matrixscreener'), ('app', 'matrix'), ('sys', '0'), ('cmd', 'load'), ('fil', '{ScanningTemplate}leicascanningtemplate')])]

# %% [markdown]
# - load *MatrixScreener* from drop down

# %%
cam.load_template(r'{ScanningTemplate}whole')
# Out:
# [OrderedDict([('cli', 'python-matrixscreener'), ('app', 'matrix'), ('sys', '0'), ('cmd', 'load'), ('fil', '{ScanningTemplate}whole')])]

# %%
cam.receive()

# %% [markdown]
# - nothing happens
# - load manually

# %%
cam.load_template(r'{ScanningTemplate}whole')
# Out:
# [OrderedDict([('cli', 'python-matrixscreener'), ('app', 'matrix'), ('sys', '0'), ('cmd', 'load'), ('fil', '{ScanningTemplate}whole')])]

# %%
cam.receive()

# %% [markdown]
# - still nothing
# - loaded template did not have CAM enabled
# - load one which has

# %%
cam.load_template(r'{ScanningTemplate}whole2')

# %%
cam.receive()
# Out:
# [OrderedDict([('cli', 'python-matrixscreener'), ('app', 'matrix'), ('sys', '0'), ('cmd', 'load'), ('fil', '{ScanningTemplate}whole2')])]

# %% [markdown]
# - loaded!
# - try loading template without CAM enabled

# %%
cam.load_template(r'{ScanningTemplate}leicascanningtemplate')

# %%
cam.receive()
# Out:
# [OrderedDict([('cli', 'python-matrixscreener'), ('app', 'matrix'), ('sys', '0'), ('cmd', 'load'), ('fil', '{ScanningTemplate}leicascanningtemplate')])]

# %% [markdown]
# - template loaded!

# %%
cam.load_template(r'{ScanningTemplate}whole2')
# Out:
# [OrderedDict([('cli', 'python-matrixscreener'), ('app', 'matrix'), ('sys', '0'), ('cmd', 'load'), ('fil', '{ScanningTemplate}whole2')])]

# %%
cam.receive()

# %% [markdown]
# - now we **cannot** load another
# - enable CAM in GUI

# %%
cam.load_template('{ScanningTemplate}whole2')

# %% [markdown]
# - loaded

# %% [markdown]
# # load same template with different positions

# %% [markdown]
# - **note** template doesnt load sometimes when changing
# - fix:
#   - use save button to the left
#   - then load again

# %%
from IPython import display
display.Image('../Capture.png')

# %%
from leicascanningtemplate import ScanningTemplate

# %%
p = b"C:\Users\TCS-User\AppData\Roaming\Leica Microsystems\LAS X\MatrixScreener\ScanningTemplates".decode()
f = p + b"\{ScanningTemplate}leicascanningtemplate.xml".decode()
tmpl = ScanningTemplate(f)

# %%
tmpl.properties.EnableCAM
# Out:
# True

# %%
tmpl.properties.ScanFieldStageStartPositionX, tmpl.properties.ScanFieldStageStartPositionY
# Out:
# (61125, 31562)

# %%
tmpl.well().attrib['FieldXStartCoordinate'], tmpl.well().attrib['FieldYStartCoordinate']
# Out:
# ('0.061125', '0.031562')

# %%
tmpl.field().FieldXCoordinate, tmpl.field().FieldYCoordinate
# Out:
# (0.061125, 0.031562)

# %%
cam.start_scan()

# %%
cam.receive()
# Out:
# [OrderedDict([('app', 'matrix'), ('sys', '0'), ('inf', 'scanfinished')])]

# %%
tmpl.move_well(1,1,0.059425130707129993-1700e-6,0.02986268490560999-1700e-6)

# %%
tmpl.write()

# %%
cam.load_template(r'{ScanningTemplate}leicascanningtemplate')

# %%
cam.start_scan()

# %%
cam.receive()
# Out:
# [OrderedDict([('app', 'matrix'), ('sys', '0'), ('inf', 'scanstart')]),
#  OrderedDict([('cli', 'python-matrixscreener'), ('app', 'matrix'), ('cmd', 'startscan/relpath:\\3.3.0_9757\\experiment--2015_03_12_14_54_20\\slide--S00\\chamber--U00--V00\\field--X00--Y00\\image--L0000--S00--U00--V00--J29--E00--O00--X00--Y00--T0000--Z00--C03.ome.tif'), ('jobname', 'Job 8')]),
#  OrderedDict([('relpath', '\\3.3.0_9757\\experiment--2015_03_12_14_54_20\\slide--S00\\chamber--U00--V00\\field--X01--Y00\\image--L0000--S00--U00--V00--J29--E00--O00--X01--Y00--T0000--Z00--C03.ome.tif'), ('jobname', 'Job 8')]),
#  OrderedDict([('relpath', '\\3.3.0_9757\\experiment--2015_03_12_14_54_20\\slide--S00\\chamber--U00--V00\\field--X01--Y01\\image--L0000--S00--U00--V00--J29--E00--O00--X01--Y01--T0000--Z00--C03.ome.tif'), ('jobname', 'Job 8')]),
# ...

# %% [markdown]
# - does not update
# - scans the same positions

# %%
cam.load_template(r'{ScanningTemplate}whole2')

# %% [markdown]
# - loads other template
# - 20-30 secs

# %%
cam.load_template(r'{ScanningTemplate}leicascanningtemplate')

# %% [markdown]
# - position updated

# %%
cam.start_scan()

# %%
from IPython import display
display.Image('../Capture.png')

# %% [markdown]
# ```
#  5:16:03 PM	 : Original Command: /cli:python-matrixscreener /app:matrix /cmd:startscan
#  5:16:03 PM	 : Client send this: python-matrixscreener
#  5:16:03 PM	 : Detected Command: eIsStartScanCommand
# ```

# %% [markdown]
# - run manually

# %%
display.Image('../Capture.PNG')

# %%
tmpl = ScanningTemplate(f)

# %%
tmpl.properties.ScanFieldStageStartPositionX, tmpl.properties.ScanFieldStageStartPositionY
# Out:
# (57725, 28162)

# %%
tmpl.move_well(1,1,57725e-6+1700e-6,28162e-6+1700e-6)

# %%
tmpl.write()

# %%
cam.load_template(r'{ScanningTemplate}whole2')

# %%
cam.load_template(r'{ScanningTemplate}leicascanningtemplate')

# %%
cam.start_scan()

# %%
display.Image('../Capture.PNG')

# %%
cam.load_template(r'{ScanningTemplate}leicascanningtemplate')

# %%
cam.receive()
# Out:
# [OrderedDict([('cli', 'python-matrixscreener'), ('app', 'matrix'), ('sys', '0'), ('cmd', 'load'), ('fil', '{ScanningTemplate}leicascanningtemplate')])]
