# %%
from leicacam import CAM

# %%
cam = CAM()

# %%
cam.start_scan()
cam.wait_for('inf')
# Out:
# OrderedDict([('app', 'matrix'), ('sys', '0'), ('inf', 'scanfinished')])

# %%
from IPython import display
display.Image("C:\\Users\\TCS-User\\Downloads\\Capture.PNG")

# %%
cam.start_scan()
cam.wait_for('inf')
# Out:
# OrderedDict([('app', 'matrix'), ('sys', '0'), ('inf', 'scanfinished')])
