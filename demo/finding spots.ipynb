# %%
from IPython import display
display.Image('/Users/arve/Desktop/Skjermbilde 2015-03-15 kl. 23.03.48.png')

# %%
# %run ../../leicaautomator/find.py

# %%
regions[0].bbox
# Out:
# (39, 1321, 153, 1438)

# %%
# %pylab inline
xs = [r.x for r in regions]
xs.sort()

ys = [r.y for r in regions]
ys.sort()

plot(xs, '.')
plot(ys, '.')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import numpy as np

# %%
x_grad = np.gradient(xs)
plot(x_grad)

x_grad.sort()
plot(x_grad)

# %%
sum(x_grad > x_grad.max()*0.5) / 2  + 1
# Out:
# 15.0

# %%
y_grad = np.gradient(ys)
plot(y_grad)

y_grad.sort()
plot(y_grad)

# %%
sum(y_grad > y_grad.max()*0.5) / 2 + 1
# Out:
# 9.0
