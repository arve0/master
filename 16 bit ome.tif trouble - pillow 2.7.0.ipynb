# %%
# !wget folk.ntnu.no/seljebu/16bit.ome.tif
# Out:
# --2015-02-05 13:11:49--  http://folk.ntnu.no/seljebu/16bit.ome.tif
# Resolving folk.ntnu.no... 129.241.56.95
# Connecting to folk.ntnu.no|129.241.56.95|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 530067 (518K) [image/tiff]
# Saving to: '16bit.ome.tif'
#
#  0% [                                       ] 0           --.-K/s
# 69% [=========================>             ] 366,240     1.74MB/s
# 100%[======================================>] 530,067     1.66MB/s   in 0.3s
#
# 2015-02-05 13:11:49 (1.66 MB/s) - '16bit.ome.tif' saved [530067/530067]

# %%
# !ls -l 16bit.ome.tif
# Out:
# -rw-r--r--  1 arve  staff  530067 Feb  5 12:56 16bit.ome.tif

# %%
import PIL
PIL.VERSION, PIL.PILLOW_VERSION
# Out:
# ('1.1.7', '2.7.0')

# %%
from PIL import Image
img = Image.open('16bit.ome.tif')
img.mode
# Out:
# 'I;16'

# %%
img.save('16bit.png') # save as 16 bit grayscale PNG
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-6-77c9dafa6935> in <module>()
# ----> 1 img.save('16bit.png') # save as 16 bit grayscale PNG
#
# /Users/arve/.virtualenvs/3.4/lib/python3.4/site-packages/PIL/Image.py in save(self, fp, format, **params)
#    1680
#    1681         try:
# -> 1682             save_handler(self, fp, filename)
#    1683         finally:
#    1684             # do what we can to clean up
#
# /Users/arve/.virtualenvs/3.4/lib/python3.4/site-packages/PIL/PngImagePlugin.py in _save(im, fp, filename, chunk, check)
#     676         rawmode, mode = _OUTMODES[mode]
#     677     except KeyError:
# --> 678         raise IOError("cannot write mode %s as PNG" % mode)
#     679
#     680     if check:
#
# OSError: cannot write mode I;16 as PNG

# %%
# %debug
# Out:
# > /Users/arve/.virtualenvs/3.4/lib/python3.4/site-packages/PIL/PngImagePlugin.py(678)_save()
#     677     except KeyError:
# --> 678         raise IOError("cannot write mode %s as PNG" % mode)
#     679
# ipdb> mode
# 'I;16'
# ipdb> rawmode
# *** NameError: name 'rawmode' is not defined
# ipdb> _OUTMODES
# {'L;1': ('L;1', b'\x01\x00'), 'RGB': ('RGB', b'\x08\x02'), 'L;2': ('L;2', b'\x02\x00'), 'I': ('I;16B', b'\x10\x00'), 'P': ('P', b'\x08\x03'), 'P;2': ('P;2', b'\x02\x03'), 'P;4': ('P;4', b'\x04\x03'), 'L': ('L', b'\x08\x00'), 'L;4': ('L;4', b'\x04\x00'), 'LA': ('LA', b'\x08\x04'), 'P;1': ('P;1', b'\x01\x03'), 'RGBA': ('RGBA', b'\x08\x06'), '1': ('1', b'\x01\x00')}
# ipdb> exit

# %%
img.mode = 'I'
img.save('16bit.png')

# %%
png_img = PIL.Image.open('16bit.png')

# %%
png_img.mode
# Out:
# 'I'

# %%
import numpy as np

# %%
img_data = np.array(img)
png_data = np.array(png_img)
np.all(img_data == png_data)
# Out:
# False

# %%
img.format_description
# Out:
# 'Adobe TIFF'

# %%
png_img.format_description
# Out:
# 'Portable network graphics'

# %%
img.info
# Out:
# {'dpi': (52858.318535656486, 52858.318535656486), 'compression': 'raw'}

# %%
# %pylab inline
imshow(img_data)
figure()
imshow(png_data);
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
img_data.shape, png_data.shape
# Out:
# ((512, 512), (512, 512))

# %%
img_data.dtype, png_data.dtype
# Out:
# (dtype('int32'), dtype('int32'))
