# %%
import matrixscreener.experiment as mse

# %%
e = mse.Experiment('data/new_software/experiment--2015_02_09_19_12_35/')

# %%
e.stitch()
# Out:
# matrixscreener stitched file already exists /Users/arve/Dokumenter/git/master/data/new_software/experiment--2015_02_09_19_12_35/stitched--U00--V00--C00--Z00.png
# ['/Users/arve/Dokumenter/git/master/data/new_software/experiment--2015_02_09_19_12_35/stitched--U00--V00--C00--Z00.png']

# %%
e.stitched
# Out:
# ['/Users/arve/Dokumenter/git/master/data/new_software/experiment--2015_02_09_19_12_35/stitched--U00--V00--C00--Z00.png']

# %%
# !ls $e.path
# Out:
# AdditionalData                   stitched--U00--V00--C00--Z00.png
# slide--S00

# %%
from IPython import display
display.Image(e.stitched[0])
